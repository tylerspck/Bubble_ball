# %%
import pandas as pd
from datetime import datetime as dt
from sportsreference.nba.boxscore import Boxscores
import numpy as np
import requests
import config
import json
import time
from pprint import pprint
your_api_key = config.API_KEY

# %%
# from sportsreference.nba.boxscore import Boxscores
# # Pulls all games from weeks 7 and 8 in 2017
# games = Boxscores(dt(2019, 1, 1), dt(2019, 12, 5))
# # Prints a dictionary of all results from January 1, 2018 and January 5,
# # 2018
# pprint(games.games)

# %%
# from sportsreference.nfl.boxscore import Boxscore

# game_data = Boxscore('202009100kan')
# print(game_data)
# print(game_data.home_points)  # Prints 33
# print(game_data.away_points)  # Prints 41
# df = game_data.dataframe  # Returns a Pandas DataFrame of game metrics
# df

# %%
# from sportsreference.nfl.roster import Player

# brees = Player('BreeDr00')
# print(brees.name)  # Prints 'Drew Brees'
# print(brees.passing_yards)  # Prints Brees' career passing yards
# # Prints a Pandas DataFrame of all relevant stats per season for Brees
# print(brees.dataframe)

# %%
# from sportsreference.nfl.roster import Roster
# print(Roster)
# saints = Roster('buf')
# for player in saints.players:
#     # Prints the name of all players who played for the New Orleans Saints
#     # in the most recent season.
#     print(player.dataframe)

# %%
# # information about each specific game api call
# import http.client

# game_id = '013dd2a7-fec4-4cc5-b819-f3cf16a1f820'
# conn = http.client.HTTPSConnection("api.sportradar.us")

# conn.request("GET", f"/nba/trial/v7/en/games/{game_id}/boxscore.xml?api_key={your_api_key}")

# res = conn.getresponse()
# data = res.read()

# pprint(data.decode("utf-8"))

# %%
# #player profile
# import http.client
# player = '37fbc3a5-0d10-4e22-803b-baa2ea0cdb12'
# conn = http.client.HTTPSConnection("api.sportradar.us")

# conn.request("GET", f"/nba/trial/v7/en/players/{player}/profile.xml?api_key={your_api_key}")

# res = conn.getresponse()
# data = res.read()

# pprint(data.decode("utf-8"))

# %%
# #yearly schedule
# url = f'https://api.sportradar.us/nba/trial/v7/en/games/2019/REG/schedule.json?api_key={your_api_key}'       
# r = requests.get(url)
# x = r.json()
# x = x['games']
# pprint(x)

# %%
# game_ids = []
# away_teams = []
# home_teams = []
# home_pts_list = []
# away_pts_list = []

# for i in x:
#     game_id = i['id']
#     game_ids.append(game_id)
#     away_team = i['away']['id']
#     away_teams.append(away_team)
#     home_team = i['home']['id']
#     home_teams.append(home_team)
   
    

    
# season2015_df = pd.DataFrame(list(zip(game_ids, home_teams,  away_teams, )), 
#                columns =['Game_id', 'Home_Team', 'Away_Team'])

# %%
# df2015 = pd.read_csv('data_files/season2015_schedule.csv')
# df2016 = pd.read_csv('data_files/season2016_schedule.csv')
# df2017 = pd.read_csv('data_files/season2017_schedule.csv')
# df2018 = pd.read_csv('data_files/season2018_schedule.csv')
# df2019 = pd.read_csv('data_files/season2019_schedule.csv')

# df2015['Season'] = 2015 
# df2016['Season'] = 2016 
# df2017['Season'] = 2017 
# df2018['Season'] = 2018 
# df2019['Season'] = 2019 

# game_id_df = pd.concat([df2015, df2016, df2017, df2018, df2019])

# game_id_df=game_id_df[['Game_id', 'Home_Team', 'Away_Team', 'Season']]
# game_id_df
# game_id_df = game_id_df.to_csv('data_files/game_id_list.csv')
df = pd.read_csv('data_files/game_id_list.csv')
df=df[['Game_id', 'Home_Team', 'Away_Team', 'Season']]
df
# Out:
#                                    Game_id  \
# 0     0da78f13-73ac-4465-8e31-ecc3029a5dc6
# 1     5166289e-69f2-4761-854e-4c72a43d8d9c
# 2     50e4c425-e26c-4740-8cd7-897919315b23
# 3     68c96738-a127-4d74-a5eb-de5ae2af3abe
# 4     d6bc803b-1bcd-463c-bb06-da91ebac4b0a
# ...                                    ...
# 6249  d5393ffd-caf1-4557-84c0-73ec2cfa8629
# 6250  590e97b9-c5b9-478d-bc9a-b59f77822792
# 6251  dc275f69-1a7b-48ae-affb-3ac11028419d
# 6252  0640ff18-da8a-4e81-acea-f9a1444be1dd
# 6253  0fca55cb-4bc8-4646-a2e6-75d95a20270b
#
#                                  Home_Team  \
# 0     583ec773-fb46-11e1-82cb-f4ce4684ea4c
# 1     583ed056-fb46-11e1-82cb-f4ce4684ea4c
# 2     583ec825-fb46-11e1-82cb-f4ce4684ea4c
# 3     583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# 4     583ed157-fb46-11e1-82cb-f4ce4684ea4c
# ...                                    ...
# 6249  583ed157-fb46-11e1-82cb-f4ce4684ea4c
# 6250  583ecda6-fb46-11e1-82cb-f4ce4684ea4c
# 6251  583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# 6252  583ecdfb-fb46-11e1-82cb-f4ce4684ea4c
# 6253  583ecb3a-fb46-11e1-82cb-f4ce4684ea4c
#
#                                  Away_Team  Season
# 0     583ec70e-fb46-11e1-82cb-f4ce4684ea4c    2015
# 1     583ece50-fb46-11e1-82cb-f4ce4684ea4c    2015
# 2     583ecd4f-fb46-11e1-82cb-f4ce4684ea4c    2015
# 3     583ecf50-fb46-11e1-82cb-f4ce4684ea4c    2015
# 4     583ecea6-fb46-11e1-82cb-f4ce4684ea4c    2015
# ...                                    ...     ...
# 6249  583ecc9a-fb46-11e1-82cb-f4ce4684ea4c    2019
# 6250  583ed102-fb46-11e1-82cb-f4ce4684ea4c    2019
# 6251  583ecea6-fb46-11e1-82cb-f4ce4684ea4c    2019
# 6252  583ecfff-fb46-11e1-82cb-f4ce4684ea4c    2019
# 6253  583ec87d-fb46-11e1-82cb-f4ce4684ea4c    2019
#
# [6254 rows x 4 columns]

# %%
# #Game Summary
# # id_list = df['Game_id'].tolist()
# id_list = ['56b0687f-6bac-4482-9adf-87571312bb6']
# attendance_count = []
# player_fname = []
# player_lname =[]
# player_id = []
# player_position = []
# player_pts = []
# player_assist = []
# player_reboud = []
# free_throw_percent = []
# two_pt_percent = []
# three_pt_pct = []
# steals = []
# turnovers = []
# game_ids = []
# capicity = []
# team_played_for = []
# team_total_pts = []


# url = f'https://api.sportradar.us/nba/trial/v7/en/games/56b0687f-6bac-4482-9adf-87571312bb6/summary.json?api_key={your_api_key}'
# r = requests.get(url)
# print(r)
# game_stats = r.json()
# #     attendance = game_stats['attendance']
# print(game_stats)
# #     for i in game_stats:
# #         print()
# Out:
# <Response [404]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-11-a424cb3f3838> in <module>
#      24 r = requests.get(url)
#      25 print(r)
# ---> 26 game_stats = r.json()
#      27 #     attendance = game_stats['attendance']
#      28 print(game_stats)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# test= game_stats['home']['players'][3]['first_name']
# test
id_list = id_list[720:]
print(len(id_list[720:]))
print(len(id_list))
id_list = id_list[720:]

# %%
id_list = df['Game_id'].tolist()
id_list = id_list[4720:5720]
# id_list = ['56b0687f-6bac-4482-9adf-87571312bb6']
attendance_count = []
player_fname = []
player_lname =[]
player_id = []
player_position = []
player_pts = []
player_assist = []
player_reboud = []
free_throw_percent = []
two_pt_percent = []
three_pt_pct = []
steals = []
turnovers = []
game_ids = []
capicity = []
team_played_for = []
team_total_pts = []
home_away = []
data = []
win = []
tech_fouls =[]
flagrant =[]
personal_fouls = []
off_boards = []
min_played = []
game_date =[]


for game_id in id_list:
    try:
        time.sleep(1)
        url = f'https://api.sportradar.us/nba/trial/v7/en/games/{game_id}/summary.json?api_key={your_api_key}'
        r = requests.get(url)
        game_stats = r.json()
        game_id = game_stats['id']
        cap = game_stats['venue']['capacity']
        team = game_stats['home']['name']
        team_away = game_stats['away']['name']
        total_pts=game_stats['home']['points']
        away_total_pts=game_stats['away']['points']
        home_team = game_stats['home']['players']
        away_team = game_stats['away']['players']
        date = game_stats['scheduled']
        if 'attendance' in game_stats:
            x = game_stats['attendance']
        else:
            x = "Covid"


        for i in home_team:

            homeplayerfirst = i['first_name']
            homeplayerlast = i['last_name']
            homeplayerposition = i['position']
            homeplayerid = i['id']
            homeplayerpts = i['statistics']['points']
            homeplayerblocks = i['statistics']['blocks']
            homeplayerfreethrowpct = i['statistics']['free_throws_pct']
            homeplayertwoptpct = i['statistics']['two_points_pct']
            homeplayerthreeptpct = i['statistics']['three_points_pct']
            homeplayerturnover = i['statistics']['turnovers']
            homeplayerassist = i['statistics']['assists']
            homeplayerrebounds = i['statistics']['rebounds']
            homeplayersteals = i['statistics']['steals']
            homeplayeroffboards = i['statistics']['offensive_rebounds']
            homeplayertech = i['statistics']['tech_fouls']
            homeplayerflagrant = i['statistics']['flagrant_fouls']
            homeplayerpersonal = i['statistics']['personal_fouls']
            homeplayermin = i['statistics']['minutes']
            player_fname.append(homeplayerfirst)
            player_lname.append(homeplayerlast)
            player_id.append(homeplayerid)
            player_position.append(homeplayerposition)
            player_pts.append(homeplayerpts)
            player_assist.append(homeplayerassist)
            player_reboud.append(homeplayerrebounds)
            free_throw_percent.append(homeplayerfreethrowpct)
            two_pt_percent.append(homeplayertwoptpct)
            three_pt_pct.append(homeplayerthreeptpct)
            steals.append(homeplayersteals)
            turnovers.append(homeplayerturnover)
            game_ids.append(game_id)
            capicity.append(cap)
            home_away.append(1)
            attendance_count.append(x)
            team_played_for.append(team)
            team_total_pts.append(total_pts)
            tech_fouls.append(homeplayertech)
            flagrant.append(homeplayerflagrant)
            personal_fouls.append(homeplayerpersonal)
            off_boards.append(homeplayeroffboards)
            min_played.append(homeplayermin)
            game_date.append(date)
            if total_pts > away_total_pts:
                win.append(1)
            else:
                win.append(0)

        for i in away_team:

            awayplayerfirst = i['first_name']
            awayplayerlast = i['last_name']
            awayplayerposition = i['position']
            awayplayerid = i['id']
            awayplayerpts = i['statistics']['points']
            awayplayerblocks = i['statistics']['blocks']
            awayplayerfreethrowpct = i['statistics']['free_throws_pct']
            awayplayermin = i['statistics']['minutes']
            awayplayertwoptpct = i['statistics']['two_points_pct']
            awayplayerthreeptpct = i['statistics']['three_points_pct']
            awayplayerturnover = i['statistics']['turnovers']
            awayplayerassist = i['statistics']['assists']
            awayplayerrebounds = i['statistics']['rebounds']
            awayplayersteals = i['statistics']['steals']
            awayplayeroffboards = i['statistics']['offensive_rebounds']
            awayplayertech = i['statistics']['tech_fouls']
            awayplayerflagrant = i['statistics']['flagrant_fouls']
            awayplayerpersonal = i['statistics']['personal_fouls']
            player_fname.append(awayplayerfirst)
            player_lname.append(awayplayerlast)
            player_id.append(awayplayerid)
            player_position.append(awayplayerposition)
            player_pts.append(awayplayerpts)
            player_assist.append(awayplayerassist)
            player_reboud.append(awayplayerrebounds)
            free_throw_percent.append(awayplayerfreethrowpct)
            two_pt_percent.append(awayplayertwoptpct)
            three_pt_pct.append(awayplayerthreeptpct)
            steals.append(awayplayersteals)
            turnovers.append(awayplayerturnover)
            game_ids.append(game_id)
            capicity.append(cap)
            home_away.append(0)
            attendance_count.append(x)
            team_played_for.append(team_away)
            team_total_pts.append(away_total_pts)
            tech_fouls.append(awayplayertech)
            flagrant.append(awayplayerflagrant)
            personal_fouls.append(awayplayerpersonal)
            off_boards.append(awayplayeroffboards)
            min_played.append(awayplayermin)
            game_date.append(date)
            if away_total_pts > total_pts:
                win.append(1)
            else:
                win.append(0)
    except:
        print(game_id)
        
        
    stats_dict = {"First_Name":player_fname, "Last_Name":player_lname,
                  "player_id":player_id, "Position":player_position,
                  "Points":player_pts, "Free_Throw_Percent":free_throw_percent,
                  "Two_Pt_Percent": two_pt_percent,
                  "Three_Pt_Percent":three_pt_pct, "Assists":player_assist,
                  "Rebounds":player_reboud, "Offensive_Rebounds": off_boards,
                  "Steals":steals, "Personal_Fouls":personal_fouls,
                  "Flagrant_Fouls":flagrant, "Tech_Fouls":tech_fouls,
                  "Turnovers":turnovers, "Team":team_played_for,
                  "Home_Away":home_away, "win":win, 
                  "Team_points":team_total_pts, "Min_played":min_played, 
                  "Crowd":attendance_count, "Stadium_Cap":capicity,
                  "game_id":game_ids, "game_date":game_date,
                  
                  
                 }
# Out:
# 359d1b8e-095a-4d04-bde4-5d5051185621
# 95f94514-90a9-4dd5-abbc-ce6b86f01d1e
# 4af41260-cf28-4e34-a69d-1e680a70bb6e
# 083396a1-fdc7-45e7-816f-486a9d058e57
# 152f160d-8ce9-4b65-bb3e-6463e66a0d5f
# 582d618e-f402-4bd3-9366-d72b6b7628a9
# f2453271-e543-4a69-9fa4-433dd1a1710b
# faaf3b96-a5df-4712-8729-8e5e4f9f25fc
# efd16646-e15b-465e-bf6c-f7fb95ff63ce
# b89c88ad-3975-4bf4-8cf4-8e949efe9612
# f7af77ad-e519-4acc-a339-19dd1d5c95f8
# ce2c3423-98b1-4dca-95ba-609f110f2b9f
# c50dff33-c30d-4e7e-b07c-b10189f974e2
# 51f6276a-356c-48df-ac57-9c766ab0843a
# 0af68821-144b-4536-9e02-51ec46b7bfd0
# 06a6890a-b4c3-4fce-aaa6-2891d2580a13
# a5f3107c-3900-4788-949f-567256329659
# 2ffde34e-f8ce-44df-9cfa-5bc40c238b2e
# 5c533626-4efe-4f73-b7c4-abbfd6c1fb97
# 6b55cae8-22fa-4ecd-8ae3-50fcba35dcbc
# 6119ca1c-6ff5-4af3-ac17-4913c3a7e9da
# 897436fa-9c0c-4171-8ac3-093701893b6f
# 9b5a7770-4ea2-472f-bd50-e10090479545
# d31f0ecd-66ef-4c4b-aaad-84ae83b13f3c
# 441f0c83-a390-48df-a967-ae4a5d5a47a6
# c570f546-8590-4cc5-b158-c91cf82cfdc1
# 4772ffc9-82bc-45a8-a8f6-d49f367b504d
# 4ef9b131-23bd-46e5-9e2d-33c68dfd2d84
# b5fa3896-1d61-4a0f-a19a-b6d36bb3233b
# 3ccb42ad-e11d-40e3-acc2-50c6288f4860
# 52f29b1b-c394-4f71-86cf-4c0bb72f438d
# 8144c3b1-c4c5-4f66-a6fc-3fb380000e71
# 9807eedd-785f-4284-b28f-1449e818c531
# 0b32d828-bc8f-4ffd-a5e6-227ff7d12c54
# 858dd8aa-036b-4277-888e-f1f15c38790d
# c02e128c-3b92-49e4-a7f9-06bd37df8ee8
# b37fd9ab-e990-43f1-8cfd-7367af200258
# df9fffa6-4f8f-46b7-a816-37e42829b0dd
# b8f6e9ff-7b3e-450f-b8d0-03f585490957
# 1cb478d2-2e3b-4b38-9eab-33ad92b7497a
# b256aa1f-8bec-4b6e-81c5-784472becf62
# d92e23bd-bd2f-41ec-9990-8c9a94514750
# 39c6eb87-92c0-408f-83a8-1d95d5d64148
# 7ae3b0a8-fd75-41e1-9924-453fb7f0fc95
# deed5eab-c9c8-46fe-b79e-1f96ca05865d
# ed38ff9b-b289-4881-902f-4527c02e3e5e
# 44256215-ff4d-4e5b-ac86-9f84f166251b
# 7e4e01c8-35d8-4e88-8b6d-b873a386da6e
# 88472ec1-f484-41c7-bea6-f69d04c3fccb
# 483fba2b-874b-4027-9821-b3c5fee12e53
# 5998c898-432a-44f1-93e6-21b0c78295b1
# ad4f55fc-8e9c-4ef5-8980-bdeaac676395
# fbfa8f01-91e5-4f26-8105-f87e7ce49829
# 63036699-694c-4b8d-a34c-867062706607
# f4194775-e52b-4a9e-8069-296dcb396248
# ba712d7f-f365-4239-84ae-0cce040e1dd8
# ce547676-86f9-4714-a7fc-54ca7bd00429
# bae94225-7ed8-400a-b7a3-cad873903d88
# 33acf177-299a-4903-86d8-f5d5a3196cf4
# c60895e8-8232-43e6-b451-eda706946dff
# 8d144d8d-3fb8-4459-8d6e-bf9a719cb704
# e21b37f0-75de-4386-8388-c92aa28c0a00
# dbdf16eb-40c9-43da-875b-325c1d1c99d4
# 0c838c5b-7cf8-4648-8a43-705e177d9470
# 222977b2-b26f-4e20-912b-8e0937ba0830

# %%
player_stats_df = pd.DataFrame(stats_dict)
player_stats_df.to_csv("data_files/player_stats6.csv")
player_stats_df
print(player_stats_df['game_id'].nunique())
# Out:
# 953

# %%
# #player profile
# import http.client

# conn = http.client.HTTPSConnection("api.sportradar.us")

# conn.request("GET", f"/nba/trial/v7/en/games/2016/REG/schedule.xml?api_key={your_api_key}")

# res = conn.getresponse()
# data = res.read()

# pprint(data.decode("utf-8"))
