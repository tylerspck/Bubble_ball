# %%
import pandas as pd
from datetime import datetime as dt
from sportsreference.nba.boxscore import Boxscores
import numpy as np
import requests
import config
import json
import time
from pprint import pprint
your_api_key = config.API_KEY

# %%
from sportsreference.nba.boxscore import Boxscores
Pulls all games from weeks 7 and 8 in 2017
games = Boxscores(dt(2019, 1, 1), dt(2019, 12, 5))
# Prints a dictionary of all results from January 1, 2018 and January 5,
# 2018
pprint(games.games)

# %%
# from sportsreference.nfl.boxscore import Boxscore

# game_data = Boxscore('202009100kan')
# print(game_data)
# print(game_data.home_points)  # Prints 33
# print(game_data.away_points)  # Prints 41
# df = game_data.dataframe  # Returns a Pandas DataFrame of game metrics
# df

# %%
# from sportsreference.nfl.roster import Player

# brees = Player('BreeDr00')
# print(brees.name)  # Prints 'Drew Brees'
# print(brees.passing_yards)  # Prints Brees' career passing yards
# # Prints a Pandas DataFrame of all relevant stats per season for Brees
# print(brees.dataframe)

# %%
# from sportsreference.nfl.roster import Roster
# print(Roster)
# saints = Roster('buf')
# for player in saints.players:
#     # Prints the name of all players who played for the New Orleans Saints
#     # in the most recent season.
#     print(player.dataframe)

# %%
# # information about each specific game api call
# import http.client

# game_id = '013dd2a7-fec4-4cc5-b819-f3cf16a1f820'
# conn = http.client.HTTPSConnection("api.sportradar.us")

# conn.request("GET", f"/nba/trial/v7/en/games/{game_id}/boxscore.xml?api_key={your_api_key}")

# res = conn.getresponse()
# data = res.read()

# pprint(data.decode("utf-8"))

# %%
# #player profile
# import http.client
# player = '37fbc3a5-0d10-4e22-803b-baa2ea0cdb12'
# conn = http.client.HTTPSConnection("api.sportradar.us")

# conn.request("GET", f"/nba/trial/v7/en/players/{player}/profile.xml?api_key={your_api_key}")

# res = conn.getresponse()
# data = res.read()

# pprint(data.decode("utf-8"))

# %%
#yearly schedule
year_list =['2014', '2015', '2016, 2017', '2018', '2019']

for year in year_list:
    url = f'https://api.sportradar.us/nba/trial/v7/en/games/2014/REG/schedule.json?api_key=3spgxv7she273wd96cs3t965'       
    r = requests.get(url).json
#     print(r)
#     x = r.json()
    x = r['games']
    pprint(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e47730e16ff6> in <module>
#       7 #     print(r)
#       8 #     x = r.json()
# ----> 9     x = r['games']
#      10     pprint(x)
#
# TypeError: 'method' object is not subscriptable

# %%
year_list =['2014', '2015', '2016', '2017', '2018', '2019']

for year in year_list:
    url = f'https://api.sportradar.us/nba/trial/v7/en/games/{year}/REG/schedule.json?api_key=3spgxv7she273wd96cs3t965'       
    r = requests.get(url)
    x = r.json()
    x = x['games']
#     pprint(x)
    game_ids = []
    away_teams = []
    home_teams = []
    home_pts_list = []
    away_pts_list = []

    for i in x:
        game_id = i['id']
        game_ids.append(game_id)
        away_team = i['away']['id']
        away_teams.append(away_team)
        home_team = i['home']['id']
        home_teams.append(home_team)

    

    
schedule_df = pd.DataFrame(list(zip(game_ids, home_teams,  away_teams, )), 
               columns =['Game_id', 'Home_Team', 'Away_Team'])

schedule_df
# Out:
#                                    Game_id  \
# 0     c5f0698c-db24-428f-8160-52fe2b67fa08
# 1     a3f57f53-12cd-490c-831b-600be0d1041d
# 2     12112637-31c6-4a7c-a8a3-e7468be47453
# 3     dccc2abc-a287-4e6d-be04-59468dc49f21
# 4     dd40d60f-c095-4450-92b6-1354cf8b836d
# ...                                    ...
# 1316  d5393ffd-caf1-4557-84c0-73ec2cfa8629
# 1317  590e97b9-c5b9-478d-bc9a-b59f77822792
# 1318  dc275f69-1a7b-48ae-affb-3ac11028419d
# 1319  0640ff18-da8a-4e81-acea-f9a1444be1dd
# 1320  0fca55cb-4bc8-4646-a2e6-75d95a20270b
#
#                                  Home_Team  \
# 0     583ecda6-fb46-11e1-82cb-f4ce4684ea4c
# 1     583ecdfb-fb46-11e1-82cb-f4ce4684ea4c
# 2     583ec97e-fb46-11e1-82cb-f4ce4684ea4c
# 3     583ed157-fb46-11e1-82cb-f4ce4684ea4c
# 4     583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# ...                                    ...
# 1316  583ed157-fb46-11e1-82cb-f4ce4684ea4c
# 1317  583ecda6-fb46-11e1-82cb-f4ce4684ea4c
# 1318  583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# ...

# %%
# df2015 = pd.read_csv('data_files/season2015_schedule.csv')
# df2016 = pd.read_csv('data_files/season2016_schedule.csv')
# df2017 = pd.read_csv('data_files/season2017_schedule.csv')
# df2018 = pd.read_csv('data_files/season2018_schedule.csv')
# df2019 = pd.read_csv('data_files/season2019_schedule.csv')

# df2015['Season'] = 2015 
# df2016['Season'] = 2016 
# df2017['Season'] = 2017 
# df2018['Season'] = 2018 
# df2019['Season'] = 2019 

# game_id_df = pd.concat([df2015, df2016, df2017, df2018, df2019])

# game_id_df=game_id_df[['Game_id', 'Home_Team', 'Away_Team', 'Season']]
# game_id_df
# game_id_df = game_id_df.to_csv('data_files/game_id_list.csv')
df = pd.read_csv('../data_files/game_id_list.csv')
df=df[['Game_id', 'Home_Team', 'Away_Team', 'Season']]
df
# Out:
#                                    Game_id  \
# 0     0da78f13-73ac-4465-8e31-ecc3029a5dc6
# 1     5166289e-69f2-4761-854e-4c72a43d8d9c
# 2     50e4c425-e26c-4740-8cd7-897919315b23
# 3     68c96738-a127-4d74-a5eb-de5ae2af3abe
# 4     d6bc803b-1bcd-463c-bb06-da91ebac4b0a
# ...                                    ...
# 6249  d5393ffd-caf1-4557-84c0-73ec2cfa8629
# 6250  590e97b9-c5b9-478d-bc9a-b59f77822792
# 6251  dc275f69-1a7b-48ae-affb-3ac11028419d
# 6252  0640ff18-da8a-4e81-acea-f9a1444be1dd
# 6253  0fca55cb-4bc8-4646-a2e6-75d95a20270b
#
#                                  Home_Team  \
# 0     583ec773-fb46-11e1-82cb-f4ce4684ea4c
# 1     583ed056-fb46-11e1-82cb-f4ce4684ea4c
# 2     583ec825-fb46-11e1-82cb-f4ce4684ea4c
# 3     583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# 4     583ed157-fb46-11e1-82cb-f4ce4684ea4c
# ...                                    ...
# 6249  583ed157-fb46-11e1-82cb-f4ce4684ea4c
# 6250  583ecda6-fb46-11e1-82cb-f4ce4684ea4c
# 6251  583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# ...

# %%
id_list = df['Game_id'].tolist()
id_list
# Out:
# ['0da78f13-73ac-4465-8e31-ecc3029a5dc6',
#  '5166289e-69f2-4761-854e-4c72a43d8d9c',
#  '50e4c425-e26c-4740-8cd7-897919315b23',
#  '68c96738-a127-4d74-a5eb-de5ae2af3abe',
#  'd6bc803b-1bcd-463c-bb06-da91ebac4b0a',
#  '229dae58-efe0-4b0c-9c69-ac68da9a8ac9',
#  '61931540-e1da-4d3c-a0b8-463e741f9096',
#  '4f175f45-5eb2-453c-b0c8-e1ef18e1566e',
#  'a7078756-0963-4c68-872c-9b677f786a5e',
#  'c2b3351c-aa9a-44aa-8f8e-40e5c9ad7e40',
#  'c2bd8052-895f-4826-81d0-f31899ace531',
#  'b6118ac0-b859-4fdd-987b-84f45f826c87',
#  '16f0d92f-1207-470d-9675-1a0af390bca4',
#  '19e4fa8f-86c2-47d6-86fb-cf4bcca0822b',
#  '1822fc8b-f7d0-4976-9099-a6fc7ce57bc7',
#  '4d0f42bc-c7c7-4521-885f-08871e22ab6e',
#  'c2510583-d8c5-4ebd-af56-2459ef8e077a',
#  'e72c8696-7107-46fc-adea-c5c2b448b610',
#  '7d7e9426-a4bd-49b6-a8b4-ddd0a5382810',
#  '8913f783-022e-4a76-91c9-4525ffcc612e',
#  '3d1bb1b4-1405-4fcb-980c-caeafbc8e7fd',
#  'b890c47f-b52c-4d7d-9861-69e15098eaf5',
#  'bf1ed357-90a5-4fea-8cdd-df0f03f2933f',
# ...

# %%
#Game Summary
# id_list = df['Game_id'].tolist()
id_list = ['56b0687f-6bac-4482-9adf-87571312bb6']
attendance_count = []
player_fname = []
player_lname =[]
player_id = []
player_position = []
player_pts = []
player_assist = []
player_reboud = []
free_throw_percent = []
two_pt_percent = []
three_pt_pct = []
steals = []
turnovers = []
game_ids = []
capicity = []
team_played_for = []
team_total_pts = []


url = f'https://api.sportradar.us/nba/trial/v7/en/games/56b0687f-6bac-4482-9adf-87571312bb6/summary.json?api_key=3spgxv7she273wd96cs3t965'
r = requests.get(url)
print(r)
game_stats = r.json()
#     attendance = game_stats['attendance']
print(game_stats)
#     for i in game_stats:
#         print()
# Out:
# <Response [404]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-2b7c714b4f6e> in <module>
#      24 r = requests.get(url)
#      25 print(r)
# ---> 26 game_stats = r.json()
#      27 #     attendance = game_stats['attendance']
#      28 print(game_stats)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
# test= game_stats['home']['players'][3]['first_name']
# test
id_list = id_list[720:]
print(len(id_list[720:]))
print(len(id_list))
id_list = df['Game_id'].tolist()
id_list = id_list[2720:3720]
id_list
# Out:
# 0
# 0
# ['4eee1952-18c2-4852-bdbf-1564972d34f2',
#  '8d69e7f5-fe9c-4706-8e80-4fede4094d57',
#  'dcaa8695-0602-4bc6-b2e9-c5858633c2ea',
#  '69bd1b3f-7a41-4319-942b-b710f741f590',
#  '819ffc20-872e-4d32-af87-13d8b716cbb5',
#  'cd5aefea-b24f-46fd-9d32-0b0a518edbae',
#  '052505fb-0eb4-4994-99f8-db7ee63651c1',
#  '0562fed2-aba5-4255-b6cb-88cfc8385597',
#  '483eb62a-5620-40a1-a770-7564ee1fd9df',
#  'a17bcd32-9e09-4a59-bd8a-66935b743950',
#  'f08ad520-2a17-4b39-9fec-a49d544bd3ed',
#  'ea6fad4c-ce9e-42d4-b4f7-7fa97143bfd0',
#  'ec2cd41d-c7aa-404d-b5fc-3db644cf7562',
#  '98bc84af-405c-4a67-8fe2-91cf67a45af2',
#  '1b86a488-abbc-42d1-9640-83e7c2d12503',
#  '25c958a2-985f-4758-9ecc-fc9f5bad73ae',
#  'dc6fc546-6a06-4766-a530-a43c1eed6340',
#  '384908e8-07bd-4965-a871-46c1f2f3bcbf',
#  '44a63dca-e871-4c93-8d2a-6753bbc64103',
#  '8f4107b9-9475-4f29-bbc0-7e45aacfc0aa',
#  'f9bd5d03-30f5-4c33-b44a-e11754765db3',
#  '03a9ee1d-83f4-4eb3-bf12-882a0418d2e2',
#  'e65195b5-7111-4d60-8096-02417face0a1',
# ...

# %%
id_list = df['Game_id'].tolist()

# id_list = ['e913a82a-a7fe-492d-a22c-5097f68d9345']
attendance_count = []
player_fname = []
player_lname =[]
player_id = []
player_position = []
player_pts = []
player_assist = []
player_reboud = []
free_throw_percent = []
two_pt_percent = []
three_pt_pct = []
steals = []
turnovers = []
game_ids = []
capicity = []
team_played_for = []
team_total_pts = []
home_away = []
data = []
win = []
tech_fouls =[]
flagrant =[]
personal_fouls = []
off_boards = []
min_played = []
game_date =[]


for game_id in id_list:
    try:
        time.sleep(1)
        url = f'https://api.sportradar.us/nba/trial/v7/en/games/{game_id}/summary.json?api_key={your_api_key}'
        r = requests.get(url)
        game_stats = r.json()
#         print(r)
#         pprint(game_stats)
        game_id = game_stats['id']
        cap = game_stats['venue']['capacity']
        team = game_stats['home']['name']
        team_away = game_stats['away']['name']
        total_pts=game_stats['home']['points']
        away_total_pts=game_stats['away']['points']
        home_team = game_stats['home']['players']
        away_team = game_stats['away']['players']
        date = game_stats['scheduled']
        if 'attendance' in game_stats:
            x = game_stats['attendance']
        else:
            x = "Covid"


        for i in home_team:

            homeplayerfirst = i['first_name']
            homeplayerlast = i['last_name']
            homeplayerposition = i['position']
            homeplayerid = i['id']
            homeplayerpts = i['statistics']['points']
            homeplayerblocks = i['statistics']['blocks']
            homeplayerfreethrowpct = i['statistics']['free_throws_pct']
            homeplayertwoptpct = i['statistics']['two_points_pct']
            homeplayerthreeptpct = i['statistics']['three_points_pct']
            homeplayerturnover = i['statistics']['turnovers']
            homeplayerassist = i['statistics']['assists']
            homeplayerrebounds = i['statistics']['rebounds']
            homeplayersteals = i['statistics']['steals']
            homeplayeroffboards = i['statistics']['offensive_rebounds']
            homeplayertech = i['statistics']['tech_fouls']
            homeplayerflagrant = i['statistics']['flagrant_fouls']
            homeplayerpersonal = i['statistics']['personal_fouls']
            homeplayermin = i['statistics']['minutes']
            homeplayerquarterstats=i['statistics']['periods']
            player_fname.append(homeplayerfirst)
            player_lname.append(homeplayerlast)
            player_id.append(homeplayerid)
            player_position.append(homeplayerposition)
            player_pts.append(homeplayerpts)
            player_assist.append(homeplayerassist)
            player_reboud.append(homeplayerrebounds)
            free_throw_percent.append(homeplayerfreethrowpct)
            two_pt_percent.append(homeplayertwoptpct)
            three_pt_pct.append(homeplayerthreeptpct)
            steals.append(homeplayersteals)
            turnovers.append(homeplayerturnover)
            game_ids.append(game_id)
            capicity.append(cap)
            home_away.append(1)
            attendance_count.append(x)
            team_played_for.append(team)
            team_total_pts.append(total_pts)
            tech_fouls.append(homeplayertech)
            flagrant.append(homeplayerflagrant)
            personal_fouls.append(homeplayerpersonal)
            off_boards.append(homeplayeroffboards)
            min_played.append(homeplayermin)
            game_date.append(date)
            if total_pts > away_total_pts:
                win.append(1)
            else:
                win.append(0)
            
            

        for i in away_team:

            awayplayerfirst = i['first_name']
            awayplayerlast = i['last_name']
            awayplayerposition = i['position']
            awayplayerid = i['id']
            awayplayerpts = i['statistics']['points']
            awayplayerblocks = i['statistics']['blocks']
            awayplayerfreethrowpct = i['statistics']['free_throws_pct']
            awayplayermin = i['statistics']['minutes']
            awayplayertwoptpct = i['statistics']['two_points_pct']
            awayplayerthreeptpct = i['statistics']['three_points_pct']
            awayplayerturnover = i['statistics']['turnovers']
            awayplayerassist = i['statistics']['assists']
            awayplayerrebounds = i['statistics']['rebounds']
            awayplayersteals = i['statistics']['steals']
            awayplayeroffboards = i['statistics']['offensive_rebounds']
            awayplayertech = i['statistics']['tech_fouls']
            awayplayerflagrant = i['statistics']['flagrant_fouls']
            awayplayerpersonal = i['statistics']['personal_fouls']
            player_fname.append(awayplayerfirst)
            player_lname.append(awayplayerlast)
            player_id.append(awayplayerid)
            player_position.append(awayplayerposition)
            player_pts.append(awayplayerpts)
            player_assist.append(awayplayerassist)
            player_reboud.append(awayplayerrebounds)
            free_throw_percent.append(awayplayerfreethrowpct)
            two_pt_percent.append(awayplayertwoptpct)
            three_pt_pct.append(awayplayerthreeptpct)
            steals.append(awayplayersteals)
            turnovers.append(awayplayerturnover)
            game_ids.append(game_id)
            capicity.append(cap)
            home_away.append(0)
            attendance_count.append(x)
            team_played_for.append(team_away)
            team_total_pts.append(away_total_pts)
            tech_fouls.append(awayplayertech)
            flagrant.append(awayplayerflagrant)
            personal_fouls.append(awayplayerpersonal)
            off_boards.append(awayplayeroffboards)
            min_played.append(awayplayermin)
            game_date.append(date)
            if away_total_pts > total_pts:
                win.append(1)
            else:
                win.append(0)
    except:
        print(game_id)
        
        
    stats_dict = {"First_Name":player_fname, "Last_Name":player_lname,
                  "player_id":player_id, "Position":player_position,
                  "Points":player_pts, "Free_Throw_Percent":free_throw_percent,
                  "Two_Pt_Percent": two_pt_percent,
                  "Three_Pt_Percent":three_pt_pct, "Assists":player_assist,
                  "Rebounds":player_reboud, "Offensive_Rebounds": off_boards,
                  "Steals":steals, "Personal_Fouls":personal_fouls,
                  "Flagrant_Fouls":flagrant, "Tech_Fouls":tech_fouls,
                  "Turnovers":turnovers, "Team":team_played_for,
                  "Home_Away":home_away, "win":win, 
                  "Team_points":team_total_pts, "Min_played":min_played, 
                  "Crowd":attendance_count, "Stadium_Cap":capicity,
                  "game_id":game_ids, "game_date":game_date,
                  
                  
                 }
# Out:
# eb868ce0-c2ac-4ab6-be4b-786fdd9bf81f
# f1a4ec4f-135d-4175-bbda-9bad38a9b695
# 6d496200-fe3e-418a-b879-88f3bb60674b
# 07b0b002-1891-4f07-af4f-3eb3d74401ed
# a47bf759-6a4a-4e41-aeee-8ef391b0838d
# 49e85038-47ce-4378-8a10-a2880f464d0b
# 5522bb9e-aafd-44fa-9c8c-0d7b3d118eb7
# 6dc2afde-bf56-4ee2-80dc-815cb71dab69
# 8c6b1bbf-329e-4c1c-8227-5eec03838307
# 42073f09-e963-46fe-ae8d-722ba90771fb
# acd852d8-451c-4ad3-84af-61efc5ac250f
# 383151bd-cae8-472e-af9d-377d7867cc19
# d7f488f4-e389-4f18-ba4a-31fe80848cc2
# e913a82a-a7fe-492d-a22c-5097f68d9345
# 2ae0f89f-bf66-4ea7-865c-fd4b096d1faf
# b3fa8196-648c-4a18-af9a-c0814194703f
# 63d73191-29e6-4ae6-95c5-3e0e32f40c38
# aeb1a2fd-41b4-4a56-b908-5e8b8fa06412
# 2af292dd-f4e3-491a-8226-d3296ed0bbbe
# 20017da9-6ed0-4072-bdd2-b7192718d885
# 2285ac6b-43c9-4f12-8d3e-9becf3d23c3c
# 86a90416-5eec-4290-8b23-e2e60729c2f6
# a60fde4f-ca8c-4182-9445-7613f18264e1
# bc709e17-eb9d-4db8-ae6c-1e59c5b7eb64
# 8758feab-286d-41a7-bac7-b38e1a5d015d
# ...

# %%
93799eea-008f-4dba-98ee-01c92d7a1bb5
359d1b8e-095a-4d04-bde4-5d5051185621
083396a1-fdc7-45e7-816f-486a9d058e57
f7af77ad-e519-4acc-a339-19dd1d5c95f8
ce2c3423-98b1-4dca-95ba-609f110f2b9f
06a6890a-b4c3-4fce-aaa6-2891d2580a13
2cab5414-aa53-413c-b64e-1f0aa02b4365
09798c15-448c-4eff-ab5e-2e4494f6a35f
1adf40d4-5ffe-4523-bb48-66b54e0e4c42
b9480df2-32e1-41fc-b178-f0a500bc09eb
14f7e7cb-6bab-44d7-960f-f993fd40b534
6dbbdb61-3b67-43b8-9643-a0871628d772
e3901e26-4ff7-4a30-ab87-ad63b2a73ba9
c55750a4-a5b3-4d15-94fa-1da1452300a9
e3e47192-9752-4c55-a410-aa26b70ceb49
961c26b1-44ac-448d-b9b0-137c4b4b9bdf
9dbf6d3a-3b02-4ee8-8f41-4da4299b4f4a
f37da69c-4e48-4148-888c-a017ccdfb1b4
be4ffb3d-e185-4f8f-b2fb-928f4a43e8b5
8ce6eb10-d357-4a48-ad5a-6645ac913f67
67d7f03a-e9a0-4b46-95ba-82ffebe759a6
2f5989bb-b20a-4d41-9016-b50a0b44f52d
306f75b6-cec7-4199-b64e-b20090e38b66
14d55cea-d91d-494e-8430-8ad8a8b61aa8
6b5ebc71-8cd5-448f-8c64-9ff8179a4f20
d31f0ecd-66ef-4c4b-aaad-84ae83b13f3c
df9fffa6-4f8f-46b7-a816-37e42829b0dd
fbfa8f01-91e5-4f26-8105-f87e7ce49829
33acf177-299a-4903-86d8-f5d5a3196cf4
27201b26-f1dc-4e8c-b8bc-3b18d151c1b6
8ad7fbd7-7932-401e-ad6e-ef442ee46e85
4bda43a6-0cf0-4c1c-9077-1c4895bde83b
5b40dec1-b48b-489c-9373-22571b460e42
dbaeeea4-4373-46c3-a636-c113bae9e71e
43a2ed17-6418-479e-be08-de1b13fd5f41
d72ad8ef-381c-42b9-8f4e-16aceb56fd9f
fab03fe0-b693-45b3-8a5d-accb60756586
abfc645d-1ed6-4a24-b358-5d50f59e0c5e
dabfb5ef-57fa-450a-a3c2-7a484d8173dc
96bf93ea-5ac0-4740-9518-40382186ff0d
b7753516-995e-4ad6-8616-0c8ceedfeef8
51c8328d-2958-4d75-8796-510cd53e5f0d
1e20d9b8-1064-4bcb-8532-ebdf69f24e9f
67be7681-19f5-4369-a0ed-4245ba8f498e
3c7994cc-0bba-45aa-aa61-592fb904c174
ffa21258-cf18-4117-8b5f-63275f354087
dd0a6219-d0e6-4491-85ca-a294eb811434
b4916303-5088-4532-919e-85ae74d3b730
23efcdab-df4c-4ba1-bda0-ec7c6853bae4
48f637b2-269c-4bdc-9b10-ffd6dfdf7049
7cc83e0e-0a29-4b33-94dc-a9ae29efe662
2dfe4fe6-6c51-44a7-a4ec-f3ea1b13d473
125ef356-f7eb-4635-a591-8b79a88a67da
ce0b5d26-55e7-4c71-944f-a2cf21eb0da4
fbdb544d-d316-4069-b2fe-bdea7349ed6c
b82235a0-1ad0-4cb0-b0f0-ad850e1375ce
81d750e9-d168-46fe-9d51-d2d1fc2e76c1
945b903f-acb8-45dc-a6a0-d1c261a95b10
b9f0d71b-057e-41fc-8ebf-8ec6b96efb9d
0e611bb0-9536-41e3-909c-1eaf01a2eea3
6002d59a-d83d-4ae4-aa73-8beb8950e8fe
501e3f7a-d44d-4095-b141-3dcfa758426b
7e60b9d6-7387-45c4-b4aa-9a044950013e
2b3c6689-1082-4b8e-b80e-0b10b3fc8377
c89a29ea-4318-4bb3-9283-c4e1e6ec2e9a
1dd0c73a-d2f0-49a6-9fb0-51d80c1e5447
f9a03098-bf5a-4dd0-b74c-46bb3ce6c25a
85f2d49c-0878-4382-a1a7-0befd011dd8b
157c8b34-4326-4be7-ae16-e848e776b2aa
bb272a19-24d2-4833-a899-16b55cfe7111
8d3ff532-8aeb-4079-8f22-66013e3740dc
a95657a5-0868-4db4-bea9-82cc3a36b314
2c2561b1-fa6b-4b3b-a74f-4d6200071288
89b8c65b-ea40-4fd3-b30f-b4d4d86870ec
a1d2bc2f-d7ff-431c-ab3f-42341286bc13
13b199b5-cfcf-4f62-8e98-39384974b353
e253238c-2eac-4749-b28e-9cde1aed0303
bd07993c-884c-482f-807a-1b2b6f112eb1

# %%
player_stats_df = pd.DataFrame(stats_dict)
player_stats_df.to_csv("data_files/player_stats7.csv")
player_stats_df
print(player_stats_df['game_id'].nunique())
# Out:
# 0

# %%
# #player profile
# import http.client

# conn = http.client.HTTPSConnection("api.sportradar.us")

# conn.request("GET", f"/nba/trial/v7/en/games/2016/REG/schedule.xml?api_key={your_api_key}")

# res = conn.getresponse()
# data = res.read()

# pprint(data.decode("utf-8"))
