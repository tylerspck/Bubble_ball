# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
from wordcloud import WordCloud
import seaborn as sns
import bar_chart_race as bcr
import datetime as dt

# %%
nba_top50 = pd.read_csv("Data/NBA_AllStats.csv", usecols=['player_name','Points','Position','game_date'])
nba_top50.head(10)
# Out:
#          player_name Position  Points                  game_date
# 0       LeBron James        F      19  2016-10-25T23:30:00+00:00
# 1        James Jones      G-F       5  2016-10-25T23:30:00+00:00
# 2         J.R. Smith      G-F       8  2016-10-25T23:30:00+00:00
# 3         Kay Felder        G       0  2016-10-25T23:30:00+00:00
# 4      Mike Dunleavy      G-F       4  2016-10-25T23:30:00+00:00
# 5        Mo Williams        G       0  2016-10-25T23:30:00+00:00
# 6         Kevin Love        F      23  2016-10-25T23:30:00+00:00
# 7  Richard Jefferson        F      13  2016-10-25T23:30:00+00:00
# 8       Kyrie Irving        G      29  2016-10-25T23:30:00+00:00
# 9   Tristan Thompson      C-F       0  2016-10-25T23:30:00+00:00

# %%
nba_top50['Date'] = pd.to_datetime(nba_top50['game_date'], errors='coerce')
nba_top50.dtypes
# Out:
# player_name                 object
# Position                    object
# Points                       int64
# game_date                   object
# Date           datetime64[ns, UTC]
# dtype: object

# %%
nba_top50['Date'] = nba_top50['Date'].dt.normalize()

# %%
nba_top50['Date'] = nba_top50['Date'].dt.date

# %%
nba_top50.head()
# Out:
#      player_name Position  Points                  game_date        Date
# 0   LeBron James        F      19  2016-10-25T23:30:00+00:00  2016-10-25
# 1    James Jones      G-F       5  2016-10-25T23:30:00+00:00  2016-10-25
# 2     J.R. Smith      G-F       8  2016-10-25T23:30:00+00:00  2016-10-25
# 3     Kay Felder        G       0  2016-10-25T23:30:00+00:00  2016-10-25
# 4  Mike Dunleavy      G-F       4  2016-10-25T23:30:00+00:00  2016-10-25

# %%
nba_top10 = nba_top50.groupby('player_name').sum()['Points']
nba_top10 = nba_top10.sort_values(ascending=False)
nba_top10 = nba_top10.head(10)
nba_top10
# Out:
# player_name
# Damian Lillard           9787
# Russell Westbrook        9699
# Giannis Antetokounmpo    9392
# Anthony Davis            9300
# LeBron James             9262
# Bradley Beal             9017
# DeMar DeRozan            8832
# James Harden             8683
# Kemba Walker             8524
# Karl-Anthony Towns       8408
# Name: Points, dtype: int64

# %%
nba_data = nba_top50.pivot_table(index='Date',columns='player_name',values='Points')
nba_data = nba_data[nba_top10.index.values]
nba_data
# Out:
# player_name  Damian Lillard  Russell Westbrook  Giannis Antetokounmpo  \
# Date
# 2016-10-25              NaN                NaN                    NaN
# 2016-10-26             39.0                NaN                    NaN
# 2016-10-27              NaN               32.0                   31.0
# 2016-10-28             29.0                NaN                    NaN
# 2016-10-29              NaN               51.0                    NaN
# ...                     ...                ...                    ...
# 2020-08-11             61.0               20.0                    NaN
# 2020-08-12              NaN                0.0                   12.0
# 2020-08-13              NaN                NaN                    0.0
# 2020-08-14             42.0                NaN                    NaN
# 2020-08-15              NaN                0.0                    NaN
#
# player_name  Anthony Davis  LeBron James  Bradley Beal  DeMar DeRozan  \
# Date
# 2016-10-25             NaN          19.0           NaN            NaN
# 2016-10-26             NaN           NaN           NaN           40.0
# 2016-10-27            50.0           NaN          13.0            NaN
# 2016-10-28             NaN          21.0           NaN           32.0
# 2016-10-29            45.0          23.0           NaN            NaN
# ...                    ...           ...           ...            ...
# 2020-08-11            27.0          29.0           NaN           23.0
# 2020-08-12             NaN           NaN           NaN            NaN
# 2020-08-13             0.0          17.0           NaN            0.0
# 2020-08-14             NaN           NaN           NaN            NaN
# 2020-08-15             NaN           NaN           NaN            NaN
#
# player_name  James Harden  Kemba Walker  Karl-Anthony Towns
# Date
# 2016-10-25            NaN           NaN                 NaN
# 2016-10-26            NaN           NaN                 NaN
# 2016-10-27           34.0          17.0                21.0
# 2016-10-28            NaN           NaN                 NaN
# 2016-10-29           26.0          26.5                 NaN
# ...                   ...           ...                 ...
# 2020-08-11            0.0          19.0                 NaN
# 2020-08-12           45.0           NaN                 NaN
# 2020-08-13            NaN           0.0                 NaN
# 2020-08-14            NaN           NaN                 NaN
# 2020-08-15           27.0           NaN                 NaN
#
# [651 rows x 10 columns]

# %%
nba_data = nba_data.fillna(0)
nba_data
# Out:
# player_name  Damian Lillard  Russell Westbrook  Giannis Antetokounmpo  \
# Date
# 2016-10-25              0.0                0.0                    0.0
# 2016-10-26             39.0                0.0                    0.0
# 2016-10-27              0.0               32.0                   31.0
# 2016-10-28             29.0                0.0                    0.0
# 2016-10-29              0.0               51.0                    0.0
# ...                     ...                ...                    ...
# 2020-08-11             61.0               20.0                    0.0
# 2020-08-12              0.0                0.0                   12.0
# 2020-08-13              0.0                0.0                    0.0
# 2020-08-14             42.0                0.0                    0.0
# 2020-08-15              0.0                0.0                    0.0
#
# player_name  Anthony Davis  LeBron James  Bradley Beal  DeMar DeRozan  \
# Date
# 2016-10-25             0.0          19.0           0.0            0.0
# 2016-10-26             0.0           0.0           0.0           40.0
# 2016-10-27            50.0           0.0          13.0            0.0
# 2016-10-28             0.0          21.0           0.0           32.0
# 2016-10-29            45.0          23.0           0.0            0.0
# ...                    ...           ...           ...            ...
# 2020-08-11            27.0          29.0           0.0           23.0
# 2020-08-12             0.0           0.0           0.0            0.0
# 2020-08-13             0.0          17.0           0.0            0.0
# 2020-08-14             0.0           0.0           0.0            0.0
# 2020-08-15             0.0           0.0           0.0            0.0
#
# player_name  James Harden  Kemba Walker  Karl-Anthony Towns
# Date
# 2016-10-25            0.0           0.0                 0.0
# 2016-10-26            0.0           0.0                 0.0
# 2016-10-27           34.0          17.0                21.0
# 2016-10-28            0.0           0.0                 0.0
# 2016-10-29           26.0          26.5                 0.0
# ...                   ...           ...                 ...
# 2020-08-11            0.0          19.0                 0.0
# 2020-08-12           45.0           0.0                 0.0
# 2020-08-13            0.0           0.0                 0.0
# 2020-08-14            0.0           0.0                 0.0
# 2020-08-15           27.0           0.0                 0.0
#
# [651 rows x 10 columns]

# %%
nba_data = nba_data.cumsum()
nba_data
# Out:
# player_name  Damian Lillard  Russell Westbrook  Giannis Antetokounmpo  \
# Date
# 2016-10-25              0.0                0.0                    0.0
# 2016-10-26             39.0                0.0                    0.0
# 2016-10-27             39.0               32.0                   31.0
# 2016-10-28             68.0               32.0                   31.0
# 2016-10-29             68.0               83.0                   31.0
# ...                     ...                ...                    ...
# 2020-08-11           7692.0             7057.0                 7478.0
# 2020-08-12           7692.0             7057.0                 7490.0
# 2020-08-13           7692.0             7057.0                 7490.0
# 2020-08-14           7734.0             7057.0                 7490.0
# 2020-08-15           7734.0             7057.0                 7490.0
#
# player_name  Anthony Davis  LeBron James  Bradley Beal  DeMar DeRozan  \
# Date
# 2016-10-25             0.0          19.0           0.0            0.0
# 2016-10-26             0.0          19.0           0.0           40.0
# 2016-10-27            50.0          19.0          13.0           40.0
# 2016-10-28            50.0          40.0          13.0           72.0
# 2016-10-29            95.0          63.0          13.0           72.0
# ...                    ...           ...           ...            ...
# 2020-08-11          7082.5        7076.0        7163.0         6760.0
# 2020-08-12          7082.5        7076.0        7163.0         6760.0
# 2020-08-13          7082.5        7093.0        7163.0         6760.0
# 2020-08-14          7082.5        7093.0        7163.0         6760.0
# 2020-08-15          7082.5        7093.0        7163.0         6760.0
#
# player_name  James Harden  Kemba Walker  Karl-Anthony Towns
# Date
# 2016-10-25            0.0           0.0                 0.0
# 2016-10-26            0.0           0.0                 0.0
# 2016-10-27           34.0          17.0                21.0
# 2016-10-28           34.0          17.0                21.0
# 2016-10-29           60.0          43.5                21.0
# ...                   ...           ...                 ...
# 2020-08-11         6211.0        6640.0              6300.0
# 2020-08-12         6256.0        6640.0              6300.0
# 2020-08-13         6256.0        6640.0              6300.0
# 2020-08-14         6256.0        6640.0              6300.0
# 2020-08-15         6283.0        6640.0              6300.0
#
# [651 rows x 10 columns]

# %%
bcr_html = bcr.bar_chart_race(df=nba_data, filename=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     160         try:
# --> 161             return self.avail[name]
#     162         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/bar_chart_race/_make_chart.py in make_animation(self)
#     427             if self.html:
# --> 428                 ret_val = anim.to_html5_video()
#     429                 try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1325                 # appropriate size for the tag
# -> 1326                 Writer = writers[rcParams['animation.writer']]
#    1327                 writer = Writer(codec='h264',
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     163             raise RuntimeError(
# --> 164                 'Requested MovieWriter ({}) not available'.format(name))
#     165
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-c616049455c1> in <module>
# ----> 1 bcr_html = bcr.bar_chart_race(df=nba_data, filename=None)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bar_chart_race/_make_chart.py in bar_chart_race(df, filename, orientation, sort, n_bars, fixed_order, fixed_max, steps_per_period, period_length, interpolate_period, label_bars, bar_size, period_label, period_fmt, period_summary_func, perpendicular_bar_func, figsize, cmap, title, title_size, bar_label_size, tick_label_size, shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
#     781                         figsize, cmap, title, title_size, bar_label_size, tick_label_size,
#     782                         shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
# --> 783     return bcr.make_animation()
#     784
#     785 def load_dataset(name='covid19'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bar_chart_race/_make_chart.py in make_animation(self)
#     444             else:
#     445                 message = str(e)
# --> 446             raise Exception(message)
#     447         finally:
#     448             plt.rcParams = self.orig_rcParams
#
# Exception: You do not have ffmpeg installed on your machine. Download
#                             ffmpeg from here: https://www.ffmpeg.org/download.html.
#
#                             Matplotlib's original error message below:
#
#                             Requested MovieWriter (ffmpeg) not available

# %%
# colors = dict(zip(
#         ['Damian Lillard','Russell Westbrook','Giannis Antetokounmpo','Anthony Davis','LeBron James','Bradley Beal','DeMar DeRozan','James Harden','Kemba Walker','Karl-Anthony Towns'],
#         ['#adb0ff','#ffb3ff','#90d595','#e48381','#aafbff','#f7bb5f','#eafb50','#6060c0','#ff5668','#cee5ff']
# ))

# colors

# %%
# group_lk = nba_data.set_index("player_name")['Points'].to_dict()
# group_lk

# %%
# fig, ax = plt.subplots(figsize=(15,8))

# def racing_barchart(game_date):
#     dff =nba_top50[nba_top50['game_date'].eq(game_date)].sort_values(by='Points',ascending=True).tail(10)
#     ax.barh(dff['player_name'],dff['Points'], color=[colors[group_lk[x]] for x in dff['player_name']])
# plt.show()

# racing_barchart(2016-10-25)

# %%
# nba_top50.pivot_table(index='STATE',columns='PLAYERS',values='AST')
