# %%
import pandas as pd
from datetime import datetime as dt
import requests
from pprint import pprint
import time

# %%
your_api_key = '8qz6xye6m4b279j789fau84n'

# %%
#yearly schedule
url = f'https://api.sportradar.us/nba/trial/v7/en/games/2019/REG/schedule.json?api_key={your_api_key}'       
r = requests.get(url)
x = r.json()
x = x['games']
pprint(x)
# Out:
# [{'away': {'alias': 'NOP',
#            'id': '583ecc9a-fb46-11e1-82cb-f4ce4684ea4c',
#            'name': 'New Orleans Pelicans',
#            'reference': '1610612740',
#            'sr_id': 'sr:team:5539'},
#   'away_points': 122,
#   'broadcasts': [{'channel': '245',
#                   'locale': 'National',
#                   'network': 'TNT',
#                   'type': 'TV'},
#                  {'locale': 'International', 'network': 'SN1', 'type': 'TV'}],
#   'coverage': 'full',
#   'home': {'alias': 'TOR',
#            'id': '583ecda6-fb46-11e1-82cb-f4ce4684ea4c',
#            'name': 'Toronto Raptors',
#            'reference': '1610612761',
#            'sr_id': 'sr:team:3433'},
#   'home_points': 130,
#   'id': 'c5f0698c-db24-428f-8160-52fe2b67fa08',
#   'reference': '0021900001',
#   'scheduled': '2019-10-23T00:00:00Z',
#   'sr_id': 'sr:match:19096428',
#   'status': 'closed',
#   'time_zones': {'away': 'US/Eastern',
#                  'home': 'US/Eastern',
# ...

# %%
year_list = ['2015','2016','2017','2018','2019']
game_ids = []
home_team_ids = []
away_team_ids =[]
home_team_names = []
away_team_names =[]
dates =[]
home_points = []
away_points = []
arena_names =[]
arena_addresses =[]
arena_cities = []
arena_states = []
arena_zips = []
arena_countries = []

for year in year_list:
    try:
        url = f'https://api.sportradar.us/nba/trial/v7/en/games/{year}/REG/schedule.json?api_key={your_api_key}' 
        time.sleep(5)
        r = requests.get(url)
        game_stats = r.json()
        games = game_stats['games']
        for i in games:
            game_id = i['id']
            home_team_id = i['home']['id']
            away_team_id = i['away']['id']
            home_team_name = i['home']['name']
            away_team_name = i['away']['name']
            date = i['scheduled']
            if 'home_points' in i:
                home_point = i['home_points']
            else:
                home_point = 'na'
            if 'away_points' in i:
                away_point = i['away_points']
            else:
                away_point = 'na'
            game_ids.append(game_id)
            home_team_ids.append(home_team_id)
            away_team_ids.append(away_team_id)
            home_team_names.append(home_team_name)
            away_team_names.append(away_team_name)
            dates.append(date)
            home_points.append(home_point)
            away_points.append(away_point)
    except:
        print(url)
    stats_dict = {"game_id":game_ids, "home_team_id":home_team_ids,
                  "away_team_id":away_team_ids, "home_team_name":home_team_names,
                  "away_team_name":away_team_names, "date":dates,
                  "home_points":home_points, "away_points":away_points
                 }
   
game_stats_df = pd.DataFrame(stats_dict)
game_stats_df
# Out:
#                                    game_id  \
# 0     3950bf88-7d69-45cb-957f-9b73ffca1d6e
# 1     f00b4cf7-4722-4ffb-8d6a-9d378f370228
# 2     340d3efc-27a8-4b9d-8e17-494416330c60
# 3     0218b99a-1a28-4e10-99b7-60046fc20dde
# 4     0be85182-d91e-464c-b452-124145949ea8
# ...                                    ...
# 6248  d5393ffd-caf1-4557-84c0-73ec2cfa8629
# 6249  590e97b9-c5b9-478d-bc9a-b59f77822792
# 6250  dc275f69-1a7b-48ae-affb-3ac11028419d
# 6251  0640ff18-da8a-4e81-acea-f9a1444be1dd
# 6252  0fca55cb-4bc8-4646-a2e6-75d95a20270b
#
#                               home_team_id  \
# 0     583ecb8f-fb46-11e1-82cb-f4ce4684ea4c
# 1     583ec5fd-fb46-11e1-82cb-f4ce4684ea4c
# 2     583ec825-fb46-11e1-82cb-f4ce4684ea4c
# 3     583ed157-fb46-11e1-82cb-f4ce4684ea4c
# 4     583ec9d6-fb46-11e1-82cb-f4ce4684ea4c
# ...                                    ...
# 6248  583ed157-fb46-11e1-82cb-f4ce4684ea4c
# 6249  583ecda6-fb46-11e1-82cb-f4ce4684ea4c
# 6250  583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# ...

# %%
game_stats_df.to_csv('data_files/game_stats.csv')
