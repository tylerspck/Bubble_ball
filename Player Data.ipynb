# %%
import pandas as pd
from datetime import datetime
import requests as request
from pprint import pprint
import time
from dateutil.relativedelta import relativedelta
from pprint import pprint
import numpy as np

# %% [markdown]
# # NBA Player Data Combination

# %%
#NBA API Key
from config import nba_key

# %%
#Player stats combination
player1 = 'data_files/player_stats1.csv'
player2 = 'data_files/player_stats2.csv'
player3 = 'data_files/player_stats3.csv'
player4 = 'data_files/player_stats4.csv'
player5 = 'data_files/player_stats5.csv'
player6 = 'data_files/player_stats6.csv'
player7 = 'data_files/player_stats7.csv'

# %%
player1DF= pd.read_csv(player1)
player2DF= pd.read_csv(player2)
player3DF= pd.read_csv(player3)
player4DF= pd.read_csv(player4)
player5DF= pd.read_csv(player5)
player6DF= pd.read_csv(player6)
player7DF= pd.read_csv(player7)

# %%
frames = [player1DF,player2DF,player3DF,player4DF,player5DF,player6DF,player7DF]

AllStats = pd.concat(frames)

#AllStats.head()

# %%
# AllStats.to_csv("data_files/NBA_AllStats.csv")

# %% [markdown]
# # Sports Reference

# %%
from sportsreference.nba.roster import Roster
from sportsreference.nba.roster import Player
from sportsreference.nba.teams import Teams

# %%
### Already ran the package and pulled data to CSV. Hashed out so it does not run again and slow down the computer
## Function to get player info from Player class object.
# def get_player_df(player):
    
#     # helper function to get player age during each season.
#     def get_age(year, bd):
#         if year[0] == "Career":
#             return None
#         else:
#             year_dt = datetime(int(year[0][0:4]) + 1, 1, 1)
#             age_years = relativedelta(year_dt, bd).years + relativedelta(year_dt, bd).months/12
#             return age_years
        
#     # helper function to get year for each row and denote
#     # rows that contain career totals.
#     def get_year(ix):
#         if ix[0] == "Career":
#             return "Career"
#         elif ix[0] == "1999-00":
#             return "2000"
#         else:
#             return ix[0][0:2] + ix[0][-2:]
    
#     # get player df and add some extra info
#     player_df = player.dataframe
#     player_df['birth_date'] = player.birth_date
#     player_df['player_id'] = player.player_id
#     player_df['name'] = player.name
#     player_df['year'] = [get_year(ix) for ix in player_df.index]
#     player_df['id'] = [player_id + ' ' + year for player_id,
#                        year in zip(player_df['player_id'],
#                        player_df['year'])]
#     player_df['age'] = [get_age(year, bd) for year,
#                         bd in zip(player_df.index,
#                         player_df['birth_date'])]
#     player_df.set_index('id', drop = True, inplace = True)
    
#     return player_df

# %%
### Already ran the package and pulled data to CSV. Hashed out so it does not run again and slow down the computer
## initialize a list of players that we have pulled data for
# players_collected = []
# season_df_init = 0
# career_df_init = 0
# season_df = 0
# career_df = 0
# # iterate through years.
# for year in range(2020, 1999, -1):
#     print('\n' + str(year))
        
#     # iterate through all teams in that year.
#     for team in Teams(year = str(year)).dataframes.index:
#         print('\n' + team + '\n')
        
#         # iterate through every player on a team roster.
#         for player_id in Roster(team, year = year,
#                          slim = True).players.keys():
            
#             # only pull player info if that player hasn't
#             # been pulled already.
#             if player_id not in players_collected:
                
#                 player = Player(player_id)
#                 player_info = get_player_df(player)
#                 player_seasons = player_info[
#                                  player_info['year'] != "Career"]
#                 player_career = player_info[
#                                 player_info['year'] == "Career"]
                
#                 # create season_df if not initialized
#                 if not season_df_init:
#                     season_df = player_seasons
#                     season_df_init = 1
                
#                 # else concatenate to season_df
#                 else:
#                     season_df = pd.concat([season_df,
#                                    player_seasons], axis = 0)
                    
#                 if not career_df_init:
#                     career_df = player_career
#                     career_df_init = 1
                
#                 # else concatenate to career_df
#                 else:
#                     career_df = pd.concat([career_df,
#                                    player_career], axis = 0)
                
#                 # add player to players_collected
#                 players_collected.append(player_id)
#                 print(player.name)

# %%
# season_df.to_csv('nba_player_stats_by_season.csv')
# career_df.to_csv('nba_player_stats_by_career.csv')

# %%
# season_df.head()

# %%
PlayerCSV = 'nba_player_stats_by_season.csv'
PlayerDF= pd.read_csv(PlayerCSV)

PlayerDF.head()
# Out:
#                id  and_ones  assist_percentage  assists  block_percentage  \
# 0  klebima01 2018       NaN                6.4     51.0               3.5
# 1  klebima01 2019       NaN                6.8     70.0               4.4
# 2  klebima01 2020       NaN                6.3     88.0               3.8
# 3  wrighde01 2016       NaN               22.5     31.0               1.1
# 4  wrighde01 2017       NaN               18.2     57.0               2.1
#
#    blocking_fouls  blocks  box_plus_minus  center_percentage  \
# 0             NaN    47.0            -0.5                0.0
# 1             NaN    78.0             0.4                0.0
# 2             NaN    83.0             0.4                0.0
# 3             NaN     3.0             0.9                0.0
# 4             NaN    11.0             2.0                0.0
#
#    defensive_box_plus_minus  ...  two_pointers_assisted_percentage  \
# 0                       0.5  ...                               NaN
# 1                       1.2  ...                               NaN
# 2                       0.0  ...                               NaN
# 3                      -0.3  ...                               NaN
# 4                       2.1  ...                               NaN
#
#    usage_percentage  value_over_replacement_player  weight  win_shares  \
# 0              13.7                            0.5   240.0         2.8
# 1              13.5                            0.9   240.0         3.5
# 2              13.9                            1.1   240.0         4.8
# 3              22.1                            0.2   185.0         0.6
# 4              16.6                            0.5   185.0         1.1
#
#    win_shares_per_48_minutes  birth_date          name  year        age
# 0                      0.113  1992-01-29   Maxi Kleber  2018  25.916667
# 1                      0.111  1992-01-29   Maxi Kleber  2019  26.916667
# 2                      0.123  1992-01-29   Maxi Kleber  2020  27.916667
# 3                      0.124  1992-04-26  Delon Wright  2016  23.666667
# 4                      0.117  1992-04-26  Delon Wright  2017  24.666667
#
# [5 rows x 94 columns]

# %%
PlayerDF[['PlayerID','Season']]=PlayerDF.id.str.split(expand=True)

PlayerDF.head()
# Out:
#                id  and_ones  assist_percentage  assists  block_percentage  \
# 0  klebima01 2018       NaN                6.4     51.0               3.5
# 1  klebima01 2019       NaN                6.8     70.0               4.4
# 2  klebima01 2020       NaN                6.3     88.0               3.8
# 3  wrighde01 2016       NaN               22.5     31.0               1.1
# 4  wrighde01 2017       NaN               18.2     57.0               2.1
#
#    blocking_fouls  blocks  box_plus_minus  center_percentage  \
# 0             NaN    47.0            -0.5                0.0
# 1             NaN    78.0             0.4                0.0
# 2             NaN    83.0             0.4                0.0
# 3             NaN     3.0             0.9                0.0
# 4             NaN    11.0             2.0                0.0
#
#    defensive_box_plus_minus  ...  value_over_replacement_player  weight  \
# 0                       0.5  ...                            0.5   240.0
# 1                       1.2  ...                            0.9   240.0
# 2                       0.0  ...                            1.1   240.0
# 3                      -0.3  ...                            0.2   185.0
# 4                       2.1  ...                            0.5   185.0
#
#    win_shares  win_shares_per_48_minutes  birth_date          name  year  \
# 0         2.8                      0.113  1992-01-29   Maxi Kleber  2018
# 1         3.5                      0.111  1992-01-29   Maxi Kleber  2019
# 2         4.8                      0.123  1992-01-29   Maxi Kleber  2020
# 3         0.6                      0.124  1992-04-26  Delon Wright  2016
# 4         1.1                      0.117  1992-04-26  Delon Wright  2017
#
#          age   PlayerID  Season
# 0  25.916667  klebima01    2018
# 1  26.916667  klebima01    2019
# 2  27.916667  klebima01    2020
# 3  23.666667  wrighde01    2016
# 4  24.666667  wrighde01    2017
#
# [5 rows x 96 columns]

# %%
#Only have years we are reviewing

PlayerDF_Seasons = PlayerDF[PlayerDF['year']>2015]
PlayerDF_Seasons.head()
# Out:
#                id  and_ones  assist_percentage  assists  block_percentage  \
# 0  klebima01 2018       NaN                6.4     51.0               3.5
# 1  klebima01 2019       NaN                6.8     70.0               4.4
# 2  klebima01 2020       NaN                6.3     88.0               3.8
# 3  wrighde01 2016       NaN               22.5     31.0               1.1
# 4  wrighde01 2017       NaN               18.2     57.0               2.1
#
#    blocking_fouls  blocks  box_plus_minus  center_percentage  \
# 0             NaN    47.0            -0.5                0.0
# 1             NaN    78.0             0.4                0.0
# 2             NaN    83.0             0.4                0.0
# 3             NaN     3.0             0.9                0.0
# 4             NaN    11.0             2.0                0.0
#
#    defensive_box_plus_minus  ...  value_over_replacement_player  weight  \
# 0                       0.5  ...                            0.5   240.0
# 1                       1.2  ...                            0.9   240.0
# 2                       0.0  ...                            1.1   240.0
# 3                      -0.3  ...                            0.2   185.0
# 4                       2.1  ...                            0.5   185.0
#
#    win_shares  win_shares_per_48_minutes  birth_date          name  year  \
# 0         2.8                      0.113  1992-01-29   Maxi Kleber  2018
# 1         3.5                      0.111  1992-01-29   Maxi Kleber  2019
# 2         4.8                      0.123  1992-01-29   Maxi Kleber  2020
# 3         0.6                      0.124  1992-04-26  Delon Wright  2016
# 4         1.1                      0.117  1992-04-26  Delon Wright  2017
#
#          age   PlayerID  Season
# 0  25.916667  klebima01    2018
# 1  26.916667  klebima01    2019
# 2  27.916667  klebima01    2020
# 3  23.666667  wrighde01    2016
# 4  24.666667  wrighde01    2017
#
# [5 rows x 96 columns]

# %%
#Reorganize column titles

PlayerData = PlayerDF_Seasons[['birth_date','name','year','age']]
PlayerData.head()
# Out:
#    birth_date          name  year        age
# 0  1992-01-29   Maxi Kleber  2018  25.916667
# 1  1992-01-29   Maxi Kleber  2019  26.916667
# 2  1992-01-29   Maxi Kleber  2020  27.916667
# 3  1992-04-26  Delon Wright  2016  23.666667
# 4  1992-04-26  Delon Wright  2017  24.666667

# %%
#Final Player Dataframe (organized)

PlayerData = PlayerData[['name','year','age','birth_date']]
PlayerData
# Out:
#                 name  year        age  birth_date
# 0        Maxi Kleber  2018  25.916667  1992-01-29
# 1        Maxi Kleber  2019  26.916667  1992-01-29
# 2        Maxi Kleber  2020  27.916667  1992-01-29
# 3       Delon Wright  2016  23.666667  1992-04-26
# 4       Delon Wright  2017  24.666667  1992-04-26
# ...              ...   ...        ...         ...
# 6128  Carlos Delfino  2019  36.333333  1982-08-29
# 6477    Jeremy Pargo  2020  33.750000  1986-03-17
# 6812    Keith Benson  2017  28.333333  1988-08-13
# 6939     Yi Jianlian  2017  29.166667  1987-10-27
# 7089    D.J. Kennedy  2017  27.083333  1989-11-05
#
# [2739 rows x 4 columns]

# %%
PlayerData.rename(columns={'name':'Player'}, inplace = True)

PlayerData
# Out:
#               Player  year        age  birth_date
# 0        Maxi Kleber  2018  25.916667  1992-01-29
# 1        Maxi Kleber  2019  26.916667  1992-01-29
# 2        Maxi Kleber  2020  27.916667  1992-01-29
# 3       Delon Wright  2016  23.666667  1992-04-26
# 4       Delon Wright  2017  24.666667  1992-04-26
# ...              ...   ...        ...         ...
# 6128  Carlos Delfino  2019  36.333333  1982-08-29
# 6477    Jeremy Pargo  2020  33.750000  1986-03-17
# 6812    Keith Benson  2017  28.333333  1988-08-13
# 6939     Yi Jianlian  2017  29.166667  1987-10-27
# 7089    D.J. Kennedy  2017  27.083333  1989-11-05
#
# [2739 rows x 4 columns]

# %%
#We pulled top 50 players for most recent season, therefore we only need players playing in 2020
PlayerData2 = PlayerData[PlayerData['year']>2019]
PlayerData2
# Out:
#                    Player  year        age  birth_date
# 2             Maxi Kleber  2020  27.916667  1992-01-29
# 7            Delon Wright  2020  27.666667  1992-04-26
# 14       Tim Hardaway Jr.  2020  27.750000  1992-03-16
# 18    Dorian Finney-Smith  2020  26.583333  1993-05-04
# 21         Justin Jackson  2020  24.750000  1995-03-28
# ...                   ...   ...        ...         ...
# 3312        Dusty Hannahs  2020  26.250000  1993-09-02
# 3321     Chandler Parsons  2020  31.166667  1988-10-25
# 3805       Derrick Walton  2020  24.666667  1995-04-03
# 3847         Josh Magette  2020  30.083333  1989-11-28
# 6477         Jeremy Pargo  2020  33.750000  1986-03-17
#
# [522 rows x 4 columns]

# %%
#Check to ensure all rows are unique
PlayerData2['Player'].nunique()
# Out:
# 522

# %%
NBATop50 = pd.read_csv('data_files/NBATope50.csv')
NBATop50.head(1)
# Out:
#                        PLAYER    PER  GP   MPG    TS%   AST    TO   USG  ORR  \
# 0  Giannis Antetokounmpo, MIL  31.94  63  30.4  0.613  16.9  11.0  37.2  7.7
#
#     DRR  REBR     VA   EWA
# 0  34.8  22.1  584.9  19.5

# %%
NBATop50[['Player','Team']]=NBATop50.PLAYER.str.split(",",expand=True)

NBATop50.head(1)
# Out:
#                        PLAYER    PER  GP   MPG    TS%   AST    TO   USG  ORR  \
# 0  Giannis Antetokounmpo, MIL  31.94  63  30.4  0.613  16.9  11.0  37.2  7.7
#
#     DRR  REBR     VA   EWA                 Player  Team
# 0  34.8  22.1  584.9  19.5  Giannis Antetokounmpo   MIL

# %%
#Combine all data to see if there are outliers. Those will be added manually

NBATop50_DF = pd.merge(NBATop50, PlayerData2, on='Player', how = "left")
#NBATop50_DF

# %%
NBATop50_Final = NBATop50_DF[['Player','Team','year','age', 'birth_date']]
#NBATop50_Final

# %%
NBATop50_Final.to_csv("data_files/NBA_Player_Profile.csv")

# %% [markdown]
# # WNBA

# %%
WNBAPlayers = pd.read_csv('data_files/FinalDataFiles/WBNAfullplayerstatslist.csv')
WNBAPlayers.head(1)
# Out:
#    Unnamed: 0 First_Name Last_Name                             player_id  \
# 0           0    Camille    Little  9951fcfb-8d31-44e5-ba85-c41ed724763d
#
#   Position  Points  Free_Throw_Percent  Two_Pt_Percent  Three_Pt_Percent  \
# 0        F       9                 0.0           0.375              20.0
#
#    Assists  ...  Turnovers  Team  Home_Away  win  Team_points  Min_played  \
# 0        1  ...          2   Sun          1    0           68    29:00:00
#
#    Crowd Stadium_Cap                               game_id  \
# 0   5846        9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
#
#                    game_date
# 0  2015-06-05T23:00:00+00:00
#
# [1 rows x 26 columns]

# %%
WNBAPlayers['player_id'].nunique()
# Out:
# 305

# %%
UniqueIDs = WNBAPlayers.drop_duplicates(subset="player_id", keep="first",inplace=False)
UniqueIDs.count().head()
# Out:
# Unnamed: 0    305
# First_Name    305
# Last_Name     305
# player_id     305
# Position      305
# dtype: int64

# %%
from config import wnba_key
api_key2 ='5mk8d3g9abmazyux3263wr29'

# %%
url = f'https://api.sportradar.us/wnba/trial/v7/en/players/adfc445c-06c0-444a-8856-32cf13a89ea2/profile.json?api_key={api_key2}'
response = request.get(url)

# %%
print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
player_list = UniqueIDs["player_id"].tolist()
player_ID = []
last_name = []
first_name = []
birthdate = []
draft_pick = []
height_inches = []
jersey_number = []
experience = []
position = []

for player_id in player_list:
    url = f'https://api.sportradar.us/wnba/trial/v7/en/players/{player_id}/profile.json?api_key={api_key2}'
    time.sleep(1)
    r = request.get(url)
    player_profiles = r.json()
    player_ID.append(player_profiles['id'])
    last_name.append(player_profiles['last_name'])
    first_name.append(player_profiles['first_name'])
    birthdate.append(player_profiles['birthdate'])
    #draft_pick.append(player_profiles['draft']['pick'])
    height_inches.append(player_profiles['height'])
    #jersey_number.append(player_profiles['jersey_number'])
    #experience.append(player_profiles['experience'])
    position.append(player_profiles['position'])

    player_dict = {"Last_Name":last_name, "First_Name":first_name,
                  "Birthday":birthdate, "Draft_Pick":draft_pick,
                  "Height_inches":height_inches, "Jersey_Number":jersey_number,
                  "Experience":experience, "Position":position,"Player_ID":player_ID
                 }
    
WNBAplayerDF = pd.DataFrame(player_dict)
WNBAplayerDF
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-fa6f709f8875> in <module>
#      18     last_name.append(player_profiles['last_name'])
#      19     first_name.append(player_profiles['first_name'])
# ---> 20     birthdate.append(player_profiles['birthdate'])
#      21     #draft_pick.append(player_profiles['draft']['pick'])
#      22     height_inches.append(player_profiles['height'])
#
# KeyError: 'birthdate'

# %%
WNBAplayerDF.to_csv("data_files/WNBA_Player_Profile.csv")

# %%
# api_key = nba_key

# %%
#Test API and review JSON
# url = f'https://api.sportradar.us/nba/trial/v7/en/players/0afbe608-940a-4d5d-a1f7-468718c67d91/profile.json?api_key={api_key}'
# response = request.get(url)

# %%
# data = response.json()

# #pprint(data)

# %%
# player_list = UniqueIDs["player_id"].tolist()
# playerID = []
# last_name = []
# first_name = []
# birthdate = []
# draft_pick = []
# height_inches = []
# jersey_number = []
# experience = []
# position = []

# for player_id in player_list:
#     url = f'https://api.sportradar.us/nba/trial/v7/en/players/{player_id}/profile.json?api_key={api_key}'
#     time.sleep(5)
#     r = request.get(url)
#     player_profiles = r.json()
        
# #     if 'jersey_number' in player_profiles['jersey_number']:
# #         jersey_number = player_profiles['jersey_number']
# #     else:
# #         jersey_number = 'none'
    
#     playerID.append(player_profiles['id'])
#     last_name.append(player_profiles['last_name'])
#     first_name.append(player_profiles['first_name'])
#     birthdate.append(player_profiles['birthdate'])
#     #draft_pick.append(player_profiles['draft']['pick'])
#     height_inches.append(player_profiles['height'])
#     #jersey_number.append(player_profiles['jersey_number'])
#     experience.append(player_profiles['experience'])
#     position.append(player_profiles['position'])

#     player_dict = {"Last_Name":last_name, "First_Name":first_name,
#                   "Birthday":birthdate, "Draft_Pick":draft_pick,
#                   "Height_inches":height_inches, "Jersey_Number":jersey_number,
#                   "Experience":experience, "Position":position,"PlayerID":playerID
#                  }
    
# playerDF = pd.DataFrame(player_dict)
# playerDF

# %%
#playerDF.to_csv(['data_files/NBA_Player_Data'])
