# %%
import pandas as pd
from datetime import datetime as dt
from sportsreference.nba.boxscore import Boxscores
import numpy as np
import requests
import config
import json
import time
from pprint import pprint
your_api_key = config.API_KEY

# %%
df = pd.read_csv('data_files/game_id_list.csv')
df=df[['Game_id', 'Home_Team', 'Away_Team', 'Season']]
df
# Out:
#                                    Game_id  \
# 0     0da78f13-73ac-4465-8e31-ecc3029a5dc6
# 1     5166289e-69f2-4761-854e-4c72a43d8d9c
# 2     50e4c425-e26c-4740-8cd7-897919315b23
# 3     68c96738-a127-4d74-a5eb-de5ae2af3abe
# 4     d6bc803b-1bcd-463c-bb06-da91ebac4b0a
# ...                                    ...
# 6249  d5393ffd-caf1-4557-84c0-73ec2cfa8629
# 6250  590e97b9-c5b9-478d-bc9a-b59f77822792
# 6251  dc275f69-1a7b-48ae-affb-3ac11028419d
# 6252  0640ff18-da8a-4e81-acea-f9a1444be1dd
# 6253  0fca55cb-4bc8-4646-a2e6-75d95a20270b
#
#                                  Home_Team  \
# 0     583ec773-fb46-11e1-82cb-f4ce4684ea4c
# 1     583ed056-fb46-11e1-82cb-f4ce4684ea4c
# 2     583ec825-fb46-11e1-82cb-f4ce4684ea4c
# 3     583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# 4     583ed157-fb46-11e1-82cb-f4ce4684ea4c
# ...                                    ...
# 6249  583ed157-fb46-11e1-82cb-f4ce4684ea4c
# 6250  583ecda6-fb46-11e1-82cb-f4ce4684ea4c
# 6251  583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# ...

# %%
id_list = df['Game_id'].tolist()
id_list = id_list[3720:4720]
# id_list = ['56b0687f-6bac-4482-9adf-87571312bb6']
attendance_count = []
player_fname = []
player_lname =[]
player_id = []
player_position = []
player_pts = []
player_assist = []
player_reboud = []
free_throw_percent = []
two_pt_percent = []
three_pt_pct = []
steals = []
turnovers = []
game_ids = []
capicity = []
team_played_for = []
team_total_pts = []
home_away = []
data = []
win = []
tech_fouls =[]
flagrant =[]
personal_fouls = []
off_boards = []
min_played = []
game_date =[]


for game_id in id_list:
    try:
        time.sleep(1)
        url = f'https://api.sportradar.us/nba/trial/v7/en/games/{game_id}/summary.json?api_key={your_api_key}'
        r = requests.get(url)
        game_stats = r.json()
        game_id = game_stats['id']
        cap = game_stats['venue']['capacity']
        team = game_stats['home']['name']
        team_away = game_stats['away']['name']
        total_pts=game_stats['home']['points']
        away_total_pts=game_stats['away']['points']
        home_team = game_stats['home']['players']
        away_team = game_stats['away']['players']
        date = game_stats['scheduled']
        if 'attendance' in game_stats:
            x = game_stats['attendance']
        else:
            x = "Covid"


        for i in home_team:

            homeplayerfirst = i['first_name']
            homeplayerlast = i['last_name']
            homeplayerposition = i['position']
            homeplayerid = i['id']
            homeplayerpts = i['statistics']['points']
            homeplayerblocks = i['statistics']['blocks']
            homeplayerfreethrowpct = i['statistics']['free_throws_pct']
            homeplayertwoptpct = i['statistics']['two_points_pct']
            homeplayerthreeptpct = i['statistics']['three_points_pct']
            homeplayerturnover = i['statistics']['turnovers']
            homeplayerassist = i['statistics']['assists']
            homeplayerrebounds = i['statistics']['rebounds']
            homeplayersteals = i['statistics']['steals']
            homeplayeroffboards = i['statistics']['offensive_rebounds']
            homeplayertech = i['statistics']['tech_fouls']
            homeplayerflagrant = i['statistics']['flagrant_fouls']
            homeplayerpersonal = i['statistics']['personal_fouls']
            homeplayermin = i['statistics']['minutes']
            player_fname.append(homeplayerfirst)
            player_lname.append(homeplayerlast)
            player_id.append(homeplayerid)
            player_position.append(homeplayerposition)
            player_pts.append(homeplayerpts)
            player_assist.append(homeplayerassist)
            player_reboud.append(homeplayerrebounds)
            free_throw_percent.append(homeplayerfreethrowpct)
            two_pt_percent.append(homeplayertwoptpct)
            three_pt_pct.append(homeplayerthreeptpct)
            steals.append(homeplayersteals)
            turnovers.append(homeplayerturnover)
            game_ids.append(game_id)
            capicity.append(cap)
            home_away.append(1)
            attendance_count.append(x)
            team_played_for.append(team)
            team_total_pts.append(total_pts)
            tech_fouls.append(homeplayertech)
            flagrant.append(homeplayerflagrant)
            personal_fouls.append(homeplayerpersonal)
            off_boards.append(homeplayeroffboards)
            min_played.append(homeplayermin)
            game_date.append(date)
            if total_pts > away_total_pts:
                win.append(1)
            else:
                win.append(0)

        for i in away_team:

            awayplayerfirst = i['first_name']
            awayplayerlast = i['last_name']
            awayplayerposition = i['position']
            awayplayerid = i['id']
            awayplayerpts = i['statistics']['points']
            awayplayerblocks = i['statistics']['blocks']
            awayplayerfreethrowpct = i['statistics']['free_throws_pct']
            awayplayermin = i['statistics']['minutes']
            awayplayertwoptpct = i['statistics']['two_points_pct']
            awayplayerthreeptpct = i['statistics']['three_points_pct']
            awayplayerturnover = i['statistics']['turnovers']
            awayplayerassist = i['statistics']['assists']
            awayplayerrebounds = i['statistics']['rebounds']
            awayplayersteals = i['statistics']['steals']
            awayplayeroffboards = i['statistics']['offensive_rebounds']
            awayplayertech = i['statistics']['tech_fouls']
            awayplayerflagrant = i['statistics']['flagrant_fouls']
            awayplayerpersonal = i['statistics']['personal_fouls']
            player_fname.append(awayplayerfirst)
            player_lname.append(awayplayerlast)
            player_id.append(awayplayerid)
            player_position.append(awayplayerposition)
            player_pts.append(awayplayerpts)
            player_assist.append(awayplayerassist)
            player_reboud.append(awayplayerrebounds)
            free_throw_percent.append(awayplayerfreethrowpct)
            two_pt_percent.append(awayplayertwoptpct)
            three_pt_pct.append(awayplayerthreeptpct)
            steals.append(awayplayersteals)
            turnovers.append(awayplayerturnover)
            game_ids.append(game_id)
            capicity.append(cap)
            home_away.append(0)
            attendance_count.append(x)
            team_played_for.append(team_away)
            team_total_pts.append(away_total_pts)
            tech_fouls.append(awayplayertech)
            flagrant.append(awayplayerflagrant)
            personal_fouls.append(awayplayerpersonal)
            off_boards.append(awayplayeroffboards)
            min_played.append(awayplayermin)
            game_date.append(date)
            if away_total_pts > total_pts:
                win.append(1)
            else:
                win.append(0)
    except:
        print(game_id)
        
        
    stats_dict = {"First_Name":player_fname, "Last_Name":player_lname,
                  "player_id":player_id, "Position":player_position,
                  "Points":player_pts, "Free_Throw_Percent":free_throw_percent,
                  "Two_Pt_Percent": two_pt_percent,
                  "Three_Pt_Percent":three_pt_pct, "Assists":player_assist,
                  "Rebounds":player_reboud, "Offensive_Rebounds": off_boards,
                  "Steals":steals, "Personal_Fouls":personal_fouls,
                  "Flagrant_Fouls":flagrant, "Tech_Fouls":tech_fouls,
                  "Turnovers":turnovers, "Team":team_played_for,
                  "Home_Away":home_away, "win":win, 
                  "Team_points":team_total_pts, "Min_played":min_played, 
                  "Crowd":attendance_count, "Stadium_Cap":capicity,
                  "game_id":game_ids, "game_date":game_date,
                  
                  
                 }
# Out:
# 4cc833b0-695d-4b46-9be3-4ca68c2d4c94
# c57cb6d4-0a38-49ec-b696-2de724be7eed
# 0c0465b5-f390-4956-83d7-1553606a8f7a
# 07b0558c-d015-4b24-9b9e-3028e84ab7c4
# 704cd865-3bcb-4588-a9da-90b73b687a22
# feaadea1-28d5-4485-aea0-47f67ce25753
# ce8a187c-4208-4ff1-9e67-5a3343a08e9d
# 4cec3757-a5a9-4a54-97ac-df130c70c964
# e8afdfae-1f15-4f3f-8511-a15a4a9d967f
# 0847ce93-3927-40e7-a773-e4a992a99ab8
# b8a77102-74fb-4840-ba3a-1bc0e4fecba2
# 2c8dafc3-5e9a-4af6-9883-d3374b1d5a37
# 08a1cda6-3ba4-4241-b0ed-86ad71b40e35
# 585a708a-0ee2-4880-807a-0f94470eeb24
# ce1066cb-c0d2-461d-9c25-c1bba1bf7de5
# e29c6f5d-15e7-4c8f-bfd4-7bf988b6cdbc
# 862b817c-8cca-4241-b7c7-bc860a934bfa
# ae6ac6ba-0623-4b32-b202-5d921fdbe845
# 5b84ba56-e31a-4c6d-8b3e-edb4127229bc
# 8456962f-90ce-4190-abf6-eca189d03c71
# e074d8be-f631-446a-8374-cedc6eb63553
# 6480ab31-b965-46e3-a615-8d98f3c32a00
# 8029f139-2384-4ba4-9abd-54e885fc49df
# 7f4af08d-af7f-4547-8f5b-eb77c2abd488
# 3d49aa5c-2b02-49c8-b1a8-b7b6d1f10acd
# ...

# %%
4cc833b0-695d-4b46-9be3-4ca68c2d4c94
c57cb6d4-0a38-49ec-b696-2de724be7eed
0c0465b5-f390-4956-83d7-1553606a8f7a
07b0558c-d015-4b24-9b9e-3028e84ab7c4
704cd865-3bcb-4588-a9da-90b73b687a22
feaadea1-28d5-4485-aea0-47f67ce25753
ce8a187c-4208-4ff1-9e67-5a3343a08e9d
4cec3757-a5a9-4a54-97ac-df130c70c964
e8afdfae-1f15-4f3f-8511-a15a4a9d967f
0847ce93-3927-40e7-a773-e4a992a99ab8
b8a77102-74fb-4840-ba3a-1bc0e4fecba2
2c8dafc3-5e9a-4af6-9883-d3374b1d5a37
08a1cda6-3ba4-4241-b0ed-86ad71b40e35
585a708a-0ee2-4880-807a-0f94470eeb24
ce1066cb-c0d2-461d-9c25-c1bba1bf7de5
e29c6f5d-15e7-4c8f-bfd4-7bf988b6cdbc
862b817c-8cca-4241-b7c7-bc860a934bfa
ae6ac6ba-0623-4b32-b202-5d921fdbe845
5b84ba56-e31a-4c6d-8b3e-edb4127229bc
8456962f-90ce-4190-abf6-eca189d03c71
e074d8be-f631-446a-8374-cedc6eb63553
6480ab31-b965-46e3-a615-8d98f3c32a00
8029f139-2384-4ba4-9abd-54e885fc49df
7f4af08d-af7f-4547-8f5b-eb77c2abd488
3d49aa5c-2b02-49c8-b1a8-b7b6d1f10acd
da29e33b-55c6-4de8-9304-bff80b04ac37
4e239ad7-c910-43f4-a7d5-f7ad5396e1b6
5839165b-2a09-4689-b8e5-4c84680eee48
dab4177c-434f-4eba-9b35-a71cda63bdd0
47adc747-08a4-4b80-8384-e17a705f1928
3473f169-ea05-4c0a-8397-0d67f375f1d8
2b921322-3c89-4cce-87aa-27610c5ef3f0
6df758c5-03d4-4dd0-8150-56cbba51d765
6d292873-e610-4108-943a-1fc1086fcee6
b9522405-fda8-4c28-ad55-035ce63624b4
f249dff7-b1f6-47b7-964f-3e996f619975
8d3d5735-e7eb-4bf0-9b46-3c0a7edd8120
b96ca2d8-2f5d-48e9-9bdf-d4ce4d299886
1a6f298f-51b5-4e88-99a0-481fcd77ed96
77ba8c6c-27cc-416d-9656-76ce83f9ea1f
4baa9a82-7f4b-4d96-8731-b3ad3b10f8bd
2760e90c-c9d7-463c-818d-e3ff67d6def7
f6a69abf-0cda-4ce9-915d-bb3825910794
44ffca9f-cf81-4476-8b41-46e9ac97700c
56c3a6fe-6f3e-45ff-ba12-5aae7c8701b3
7207e963-7c0c-4cc4-b641-4807e6f9d12c
01d0ed2f-497b-4d27-8929-2abccf83a9df
231f5f19-8721-493f-8b1b-c8179c54fac7
9fb51982-77bb-4795-a4bb-e8f86212133c
f012c944-3264-4b53-8f0e-f5e395efcfcd
2d41eb29-0338-487d-b375-332d6527b6ff
ec7762d3-0d4b-47f1-8886-62b9698e94da
3bd541c9-28a5-46c6-a49c-5d98b0b67af1
627d90e9-f58b-4490-b7ec-84341ec9d3db
c91f5ab8-f3de-4988-8509-d38f66f0f23d
0b7010e7-fa82-46db-9d5d-aa1ec26134b4
5ecfae32-4688-41bc-9882-64cf2e7ba8c1
da7c1d73-81bb-45be-b1e8-f03df55607cd
78f9471b-0601-4a7e-b6ee-b4bbdb533334
cb8e80ef-55a7-432c-8d0a-ff63a7f5b0f7
da4c1183-7400-419d-9736-e9fadd5428a3
9f848b3b-63ac-4528-98a0-39930cd56d90
5bf7dfdb-b5fb-4d13-ac9d-21c49717b9d0
036f6fe0-c277-4df9-852e-e39119e1a733
0dbcc511-5a82-4efe-8218-e2519b2278b6
cd520a60-a789-469f-a11c-3d9fca88c2ed
408e84c4-3785-4a47-ac47-8210fa6a1978
09c7a3a4-80c1-4d4a-81aa-badb468d0bf8
a1b9c3d4-aa16-4b88-ae9f-75e6289edc99
53df10a9-1a39-4e32-8b29-5cfaf3f77edb
3cce7ee0-926b-402c-be0c-ba2c1b8f04a0
45343494-6b68-4629-9139-a1086be695aa
e7f1c9b8-e250-422a-b162-645635506aa5
eadd7fb9-4962-480d-84fa-5fc150dc9770
1da1d1a0-7bab-4851-a751-0dcdb916ffef
9e1bd381-05ff-4a40-93a4-4d43eb6dd17f
a2e32b0b-6986-4c65-9fbc-33fb9e80282c
2eaae25c-2765-4099-8afb-226a782b51b9
63ab2635-055c-43eb-800e-562a44b8e17a
18811ac0-fbb2-4fa6-baa7-dbc29bf33da2
4e93e03d-5afb-465f-9aee-4c3f7918231d
0281c661-f09a-4245-9345-5b5704c0ecca
eec74740-24a2-4256-a7ba-c303bed2d52f
4f882f8d-6226-4adf-8285-8dc52d8990b5
e44fe86d-e08e-4202-b715-2cdd5681cbe2
8912a0c3-25a1-426c-a44b-96db5902fbb6
c35751fe-f0cf-40f0-851e-831ec71b178f
55aaab3c-bd6c-4518-8fa9-17da675a37b1
fa7d295c-672d-4910-9b99-63c802d24a17
d8d79cd1-f66b-4f9a-8dd2-a729b566b0a2
22567352-7e4f-4991-82e9-55ac513d2152
583468fa-0747-4492-ae49-395fe5cc7141
6092980b-8e9b-48fd-99ac-6c589b10877c
d30f1f2d-52f4-497d-808e-97c1fcc62de0
744ddcb3-791d-45d5-b80c-415c30ea84c7
ad1073fd-7bd8-4ada-aaf3-5275e48fb6b0
9c9af67a-54a2-40f2-b23d-2559431907c9
dc7ad6c9-3974-4494-a4ef-26da7bfd2607
673b2a03-5feb-48aa-b06b-4f8dcbe877fe
d2f67c76-efe9-42da-8a96-a37ea7faa66f
992e6b0f-1bd7-4bdb-a507-ef77e71ad5be
da5307fd-0c13-4b08-9527-06863ba37500
e34dd338-ad75-4685-971b-d823d9205045
4bb78cf0-1d04-4538-ae35-a83ea1f4e180
20d460c6-c510-4b10-b6cd-9208673f6aa7
c9e4652d-ae5b-4dc6-8f34-dd4b3386dc1e
c7531d06-60e8-480a-8180-554b6fe45714
dd805eb0-7941-45e2-bf81-2eef13be2473
d7615e94-18e6-4122-b9ef-11930fdae2a8
7e4d46d6-0e66-4e8f-8ab8-1d9c592a99d2
0abe0513-1287-45e7-b0bf-009100ea9440
78f17ffe-d445-4fb2-9011-ab2b22fc2790
2d0f9728-0b9f-4b4c-beec-bd0cdb3c9aef
41f032be-43ea-4d91-9da3-167a09538b24
c0dd320b-084e-433c-80b4-c9b6b5981bb0
5fe88e9a-bf75-490d-86b8-7b77aaf43c75
7b2adddd-4bf8-404d-a971-913345de2217
3964d6bb-e525-4c44-836d-cd9242b6a0ab
6e0333b6-f894-404e-8daf-0a7729f81185
648fba12-dec3-4564-8925-628ed0702ffa
75737b90-22cd-4a0c-880e-3fe57e30c9e1

# %%
player_stats_df = pd.DataFrame(stats_dict)
player_stats_df.to_csv("data_files/player_stats5.csv")
player_stats_df
print(player_stats_df['game_id'].nunique())
# Out:
# 938
