# %%
import pandas as pd
from datetime import datetime as dt
from sportsreference.nba.boxscore import Boxscores
import numpy as np
import requests
import config
import json
import time
from pprint import pprint
from WNBAconfig import API_KEY

# %%
#pull in the schedule
df = pd.read_csv('data_files/game_id_list_WNBA.csv')
df=df[['Game_id', 'Home_Team', 'Away_Team', 'Season']]
df
# Out:
#                                    Game_id  \
# 0     e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 1     51ada2d4-5260-4c88-9fed-af4bf50130ab
# 2     8c504e6b-663d-40a1-a902-2cae4d9c4470
# 3     fea52768-68e5-4af0-92f1-0c415c7b71a0
# 4     cae9c07b-96d8-48c4-9ad8-f280218846be
# ...                                    ...
# 1021  1b9746ba-eccf-46e6-a5cd-bfc44bb31c92
# 1022  35d03e56-850f-45b2-a060-c53055190aee
# 1023  4f683af4-2d4b-487d-bf92-57cd60d82045
# 1024  6ce30c91-3e9c-4418-8aa6-24fdfb47fe35
# 1025  d29ed648-b22a-4599-a9d2-b5aff367170c
#
#                                  Home_Team  \
# 0     a015b02d-845c-40c1-8ef4-844984f47e4d
# 1     08ed8274-e29f-4248-bc2e-83cc8ed18d75
# 2     6f017f37-be96-4bdc-b6d3-0a0429c72e89
# 3     3c409388-ab73-4c7f-953d-3a71062240f6
# 4     0699edf3-5993-4182-b9b4-ec935cbd4fcc
# ...                                    ...
# 1021  f073a15f-0486-4179-b0a3-dfd0294eb595
# 1022  5f0b5caf-708b-4300-92f2-53b51d83ec06
# 1023  5d70a9af-8c2b-4aec-9e68-9acc6ddb93e4
# 1024  0a5ad38d-2fe3-43ba-894b-1ba3d5042ea9
# 1025  0699edf3-5993-4182-b9b4-ec935cbd4fcc
#
#                                  Away_Team  Season
# 0     5c0d47fe-8539-47b0-9f36-d0b3609ca89b    2015
# 1     5d70a9af-8c2b-4aec-9e68-9acc6ddb93e4    2015
# 2     5f0b5caf-708b-4300-92f2-53b51d83ec06    2015
# 3     f073a15f-0486-4179-b0a3-dfd0294eb595    2015
# 4     e6bc56cc-9dad-43aa-8ccb-ee9d499fea28    2015
# ...                                    ...     ...
# 1021  a015b02d-845c-40c1-8ef4-844984f47e4d    2019
# 1022  d6a012ed-84aa-48d3-8265-2d3f3ff2199a    2019
# 1023  08ed8274-e29f-4248-bc2e-83cc8ed18d75    2019
# 1024  6f017f37-be96-4bdc-b6d3-0a0429c72e89    2019
# 1025  171b097d-01db-4ae8-9d56-035689402ec6    2019
#
# [1026 rows x 4 columns]

# %%
# check length area
id_list = id_list[720:]
print(len(id_list[720:]))
print(len(id_list))
id_list = id_list[720:]

# %%
id_list = df['Game_id'].tolist()
id_list = id_list[:1000]
# id_list = ['e83ca6b1-1257-47d2-9153-ed2c72ad85ab']
attendance_count = []
player_fname = []
player_lname =[]
player_id = []
player_position = []
player_pts = []
player_assist = []
player_reboud = []
free_throw_percent = []
two_pt_percent = []
three_pt_pct = []
steals = []
turnovers = []
game_ids = []
capicity = []
team_played_for = []
team_total_pts = []
home_away = []
data = []
win = []
tech_fouls =[]
flagrant =[]
personal_fouls = []
off_boards = []
min_played = []
game_date =[]


for game_id in id_list:
    try:
        time.sleep(1)
        url = f'http://api.sportradar.us/wnba/trial/v7/en/games/{game_id}/summary.json?api_key={API_KEY}'
        r = requests.get(url)
        game_stats = r.json()
        game_id = game_stats['id']
        cap = game_stats['venue']['capacity']
        team = game_stats['home']['name']
        team_away = game_stats['away']['name']
        total_pts=game_stats['home']['points']
        away_total_pts=game_stats['away']['points']
        home_team = game_stats['home']['players']
        away_team = game_stats['away']['players']
        date = game_stats['scheduled']
        if 'attendance' in game_stats:
            x = game_stats['attendance']
        else:
            x = "Covid"


        for i in home_team:

            homeplayerfirst = i['first_name']
            homeplayerlast = i['last_name']
            homeplayerposition = i['position']
            homeplayerid = i['id']
            homeplayerpts = i['statistics']['points']
            homeplayerblocks = i['statistics']['blocks']
            homeplayerfreethrowpct = i['statistics']['free_throws_pct']
            homeplayertwoptpct = i['statistics']['two_points_pct']
            homeplayerthreeptpct = i['statistics']['three_points_pct']
            homeplayerturnover = i['statistics']['turnovers']
            homeplayerassist = i['statistics']['assists']
            homeplayerrebounds = i['statistics']['rebounds']
            homeplayersteals = i['statistics']['steals']
            homeplayeroffboards = i['statistics']['offensive_rebounds']
            homeplayertech = i['statistics']['tech_fouls']
            homeplayerflagrant = i['statistics']['flagrant_fouls']
            homeplayerpersonal = i['statistics']['personal_fouls']
            if 'minutes' in i['statistics']:
                homeplayermin = i['statistics']['minutes']
            else:
                homeplayermin = 0
            player_fname.append(homeplayerfirst)
            player_lname.append(homeplayerlast)
            player_id.append(homeplayerid)
            player_position.append(homeplayerposition)
            player_pts.append(homeplayerpts)
            player_assist.append(homeplayerassist)
            player_reboud.append(homeplayerrebounds)
            free_throw_percent.append(homeplayerfreethrowpct)
            two_pt_percent.append(homeplayertwoptpct)
            three_pt_pct.append(homeplayerthreeptpct)
            steals.append(homeplayersteals)
            turnovers.append(homeplayerturnover)
            game_ids.append(game_id)
            capicity.append(cap)
            home_away.append(1)
            attendance_count.append(x)
            team_played_for.append(team)
            team_total_pts.append(total_pts)
            tech_fouls.append(homeplayertech)
            flagrant.append(homeplayerflagrant)
            personal_fouls.append(homeplayerpersonal)
            off_boards.append(homeplayeroffboards)
            min_played.append(homeplayermin)
            game_date.append(date)
            if total_pts > away_total_pts:
                win.append(1)
            else:
                win.append(0)

        for i in away_team:

            awayplayerfirst = i['first_name']
            awayplayerlast = i['last_name']
            awayplayerposition = i['position']
            awayplayerid = i['id']
            awayplayerpts = i['statistics']['points']
            awayplayerblocks = i['statistics']['blocks']
            awayplayerfreethrowpct = i['statistics']['free_throws_pct']
            if 'minutes' in i['statistics']:
                awayplayermin = i['statistics']['minutes']
            else:
                awayplayermin = 0
            awayplayertwoptpct = i['statistics']['two_points_pct']
            awayplayerthreeptpct = i['statistics']['three_points_pct']
            awayplayerturnover = i['statistics']['turnovers']
            awayplayerassist = i['statistics']['assists']
            awayplayerrebounds = i['statistics']['rebounds']
            awayplayersteals = i['statistics']['steals']
            awayplayeroffboards = i['statistics']['offensive_rebounds']
            awayplayertech = i['statistics']['tech_fouls']
            awayplayerflagrant = i['statistics']['flagrant_fouls']
            awayplayerpersonal = i['statistics']['personal_fouls']
            player_fname.append(awayplayerfirst)
            player_lname.append(awayplayerlast)
            player_id.append(awayplayerid)
            player_position.append(awayplayerposition)
            player_pts.append(awayplayerpts)
            player_assist.append(awayplayerassist)
            player_reboud.append(awayplayerrebounds)
            free_throw_percent.append(awayplayerfreethrowpct)
            two_pt_percent.append(awayplayertwoptpct)
            three_pt_pct.append(awayplayerthreeptpct)
            steals.append(awayplayersteals)
            turnovers.append(awayplayerturnover)
            game_ids.append(game_id)
            capicity.append(cap)
            home_away.append(0)
            attendance_count.append(x)
            team_played_for.append(team_away)
            team_total_pts.append(away_total_pts)
            tech_fouls.append(awayplayertech)
            flagrant.append(awayplayerflagrant)
            personal_fouls.append(awayplayerpersonal)
            off_boards.append(awayplayeroffboards)
            min_played.append(awayplayermin)
            game_date.append(date)
            if away_total_pts > total_pts:
                win.append(1)
            else:
                win.append(0)
    except:
        print(game_id)
        
        
    stats_dict = {"First_Name":player_fname, "Last_Name":player_lname,
                  "player_id":player_id, "Position":player_position,
                  "Points":player_pts, "Free_Throw_Percent":free_throw_percent,
                  "Two_Pt_Percent": two_pt_percent,
                  "Three_Pt_Percent":three_pt_pct, "Assists":player_assist,
                  "Rebounds":player_reboud, "Offensive_Rebounds": off_boards,
                  "Steals":steals, "Personal_Fouls":personal_fouls,
                  "Flagrant_Fouls":flagrant, "Tech_Fouls":tech_fouls,
                  "Turnovers":turnovers, "Team":team_played_for,
                  "Home_Away":home_away, "win":win, 
                  "Team_points":team_total_pts, "Min_played":min_played, 
                  "Crowd":attendance_count, "Stadium_Cap":capicity,
                  "game_id":game_ids, "game_date":game_date,
                  
                  
                 }
# Out:
# 8ad5876f-6888-4499-8635-6e433e3823d2
# 3d6a37e8-6158-41dd-9df7-1781c37ab37a
# 9b119e36-f03a-4e9c-a3b4-511fbd43630a
# 3691ec5a-9351-4301-8909-ca3e94d8d61b
# 47efb22b-68ac-4aa2-9190-81ce959a7ac9
# c95f0d1f-1c10-4074-bc1a-98d228047a03
# f840d646-a071-4557-9c91-6f9e4a14fcb6

# %%
#put missing games here
player_stats_df = pd.DataFrame(stats_dict)
player_stats_df
# Out:
#    First_Name     Last_Name                             player_id Position  \
# 0     Camille        Little  9951fcfb-8d31-44e5-ba85-c41ed724763d        F
# 1     Jasmine        Thomas  0ac8d024-ec11-4809-83f4-6277c1252617        G
# 2       Kayla      Pedersen  adfc445c-06c0-444a-8856-32cf13a89ea2        F
# 3     Allison     Hightower  eedb8366-1bff-490e-9dea-5316bbe14559        G
# 4   Elizabeth      Williams  c8672dba-0deb-4cf1-8304-82365865edaa      C-F
# 2          3  ...          0      Sun          1    0           68
# 3          0  ...          0      Sun          1    0           68
# 4          5  ...          0      Sun          1    0           68
# 5          6  ...          3      Sun          1    0           68
# 6          2  ...          1      Sun          1    0           68
# 7          0  ...          0      Sun          1    0           68
# 8          2  ...          1      Sun          1    0           68
# 9          1  ...          0      Sun          1    0           68
# 10         0  ...          0      Sun          1    0           68
# 11         2  ...          1      Sun          1    0           68
# 12         7  ...          0      Sun          1    0           68
# 13         4  ...          0  Mystics          0    1           73
# 14        12  ...          1  Mystics          0    1           73
# 15         1  ...          0  Mystics          0    1           73
# 16         0  ...          2  Mystics          0    1           73
# 17         0  ...          0  Mystics          0    1           73
# 18         4  ...          0  Mystics          0    1           73
# 19         1  ...          0  Mystics          0    1           73
# 20         2  ...          0  Mystics          0    1           73
# 21         0  ...          0  Mystics          0    1           73
# 22         4  ...          3  Mystics          0    1           73
# 23         6  ...          1  Mystics          0    1           73
# 24         7  ...          2  Mystics          0    1           73
#
#     Min_played Crowd  Stadium_Cap                               game_id  \
# 0        29:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 1        30:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 2        10:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 3            0  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 4        10:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 5        29:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 6         9:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 7            0  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 8        32:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 9         5:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 10           0  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 11        9:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 12       32:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 13       28:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 14       31:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 15        5:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 16       11:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 17           0  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 18       16:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 19        4:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 20       15:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 21       00:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 22       31:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 23       23:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
# 24       31:00  5846         9518  e83ca6b1-1257-47d2-9153-ed2c72ad85ab
#
#                     game_date
# 0   2015-06-05T23:00:00+00:00
# 1   2015-06-05T23:00:00+00:00
# 2   2015-06-05T23:00:00+00:00
# 3   2015-06-05T23:00:00+00:00
# 4   2015-06-05T23:00:00+00:00
# 5   2015-06-05T23:00:00+00:00
# 6   2015-06-05T23:00:00+00:00
# 7   2015-06-05T23:00:00+00:00
# 8   2015-06-05T23:00:00+00:00
# 9   2015-06-05T23:00:00+00:00
# 10  2015-06-05T23:00:00+00:00
# 11  2015-06-05T23:00:00+00:00
# 12  2015-06-05T23:00:00+00:00
# 13  2015-06-05T23:00:00+00:00
# 14  2015-06-05T23:00:00+00:00
# 15  2015-06-05T23:00:00+00:00
# 16  2015-06-05T23:00:00+00:00
# 17  2015-06-05T23:00:00+00:00
# 18  2015-06-05T23:00:00+00:00
# 19  2015-06-05T23:00:00+00:00
# 20  2015-06-05T23:00:00+00:00
# 21  2015-06-05T23:00:00+00:00
# 22  2015-06-05T23:00:00+00:00
# 23  2015-06-05T23:00:00+00:00
# 24  2015-06-05T23:00:00+00:00
#
# [25 rows x 25 columns]

# %%
#save file
player_stats_df = pd.DataFrame(stats_dict)
player_stats_df.to_csv("data_files/wnba_player_stats1.csv")
player_stats_df
print(player_stats_df['game_id'].nunique())
# Out:
# 993

# %%
# #player profile
# import http.client

# conn = http.client.HTTPSConnection("api.sportradar.us")

# conn.request("GET", f"/nba/trial/v7/en/games/2016/REG/schedule.xml?api_key={your_api_key}")

# res = conn.getresponse()
# data = res.read()

# pprint(data.decode("utf-8"))
